# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os

# %%
import json
with open("service1906_1506.json") as of:
    data = json.load(of)

# %%
computes = [c for c in data.keys() if c!="timespan"]
variables = [v for v in data[computes[0]] if v!='index' and v!='arrJob_scheduling']

# %%
#Check empty array
def getEmptyArr(data, c):
    cObj = data[c]
    cDf = pd.DataFrame()
    cDf['compute'] = [c for _ in data['timespan']]
    cDf['timespan'] = data['timespan']
    for v in variables:
        vArr = np.array(cObj[v])
        if len(vArr)==0:
            print('c=', c)
            print('v=', v)
for c in computes:
    getEmptyArr(data, c)
# Out:
# c= compute-1-26
# v= arrTemperature

# %%
def addTarget(cDf, predictedVar, predictedStep, target):
    cDf[target] = cDf[predictedVar].shift(-predictedStep)
    cDf.dropna(inplace=True)
    return cDf

# %%
def getComputeDf(data, c, predictedVar, predictedStep, target):
    cObj = data[c]
    cDf = pd.DataFrame()
    cDf['compute'] = [c for _ in data['timespan']]
    cDf['timespan'] = data['timespan']
    for v in variables:
        vArr = np.array(cObj[v])
        if len(vArr)==0:
            return None
        else:
            for i in range(len(vArr[0])):
                cDf[v+str(i)] = vArr[:, i]
    cDf['timespan'] = pd.to_datetime(cDf['timespan'])
    return addTarget(cDf, predictedVar, predictedStep, target)

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from IPython.display import FileLink
import codecs, json

# %%
def exportNPArrayToJson(a, fileName):
    b = a.tolist()
    json.dump(b, codecs.open(fileName, 'w', encoding='utf-8'))

# %%
def splitTrainTest(predictedVar):
    target = predictedVar + "_target"
    predictedSteps = 4
    df = pd.concat([x for x in [getComputeDf(data, c, predictedVar, predictedSteps, target) for c in computes] if type(x)!="NoneType"])
    
    df = df.reset_index().drop('index', axis=1)
    features = [x for x in df.columns if x not in ['compute', 'timespan', target]]
        
    X_dfs = []
    y = []
    numberOfSequences = 1
    # generate training data.
    for compute in computes:
        cDf = df[df['compute']==compute]
        if(len(cDf) > sequenceSteps):
            randSteps = np.random.randint(0, len(cDf)-sequenceSteps, numberOfSequences)
            for randStep in randSteps:
                X_dfs.append(cDf.iloc[randStep:randStep+sequenceSteps])
                y.append(X_dfs[-1][target].values[-1])

    X_train_dfs, X_test_dfs, y_train, y_test = train_test_split(X_dfs, y, test_size=0.33)
            
    #Scale data

    # combine the training data to create a scaler
    train_dfs = pd.concat(X_train_dfs)

    scaler = StandardScaler().fit(train_dfs[features].values)
    
    X_train = np.array([scaler.transform(item[features].values) for item in X_train_dfs])
    X_test = np.array([scaler.transform(item[features].values) for item in X_test_dfs])
    y_train = np.array(y_train)
    y_test = np.array(y_test)
    
    exportNPArrayToJson(X_train, 'newData/'+target+'_X_train_HPCC_'+str(sequenceSteps)+'.json')
    exportNPArrayToJson(X_test, 'newData/'+target+'_X_test_HPCC_'+str(sequenceSteps)+'.json')
    exportNPArrayToJson(y_train, 'newData/'+target+'_y_train_HPCC_'+str(sequenceSteps)+'.json')
    exportNPArrayToJson(y_test, 'newData/'+target+'_y_test_HPCC_'+str(sequenceSteps)+'.json')
    
    FileLink('newData/'+target+'_X_train_HPCC_'+str(sequenceSteps)+'.json')
    FileLink('newData/'+target+'_X_test_HPCC_'+str(sequenceSteps)+'.json')
    FileLink('newData/'+target+'_y_train_HPCC_'+str(sequenceSteps)+'.json')
    FileLink('newData/'+target+'_y_test_HPCC_'+str(sequenceSteps)+'.json')
    
    return (X_train, X_test, y_train, y_test)

# %%
from keras import regularizers
from keras.models import Sequential
from keras.layers import LSTM
from keras.layers import Dense
from keras.layers import Activation
from keras.layers import Dropout
from keras.layers import Flatten

# from keras import backend as K
# K.set_session(K.tf.Session(config=K.tf.ConfigProto(intra_op_parallelism_threads=36, inter_op_parallelism_threads=36)))


def createModel(l1Nodes, l2Nodes, d1Nodes, d2Nodes, inputShape):
    # input layer
    lstm1 = LSTM(l1Nodes, input_shape=inputShape, return_sequences=True, kernel_regularizer=regularizers.l2(0.1))
    do1 = Dropout(0.2)
    
    lstm2 = LSTM(l2Nodes, return_sequences=True, kernel_regularizer=regularizers.l2(0.1))
    do2 = Dropout(0.2)
    
    flatten = Flatten()
    
    dense1 = Dense(d1Nodes, activation='relu')
    do3 = Dropout(0.2)
    
    dense2 = Dense(d2Nodes, activation='relu')
    do4 = Dropout(0.2)
    
    # output layer
    outL = Dense(1, activation='relu')
    # combine the layers
#     layers = [lstm1, do1, lstm2, do2, dense1, do3, dense2, do4, outL]
    layers = [lstm1, lstm2, flatten,  dense1, dense2, outL]
#     layers = [lstm1, flatten,  dense1, outL]

    # create the model
    model = Sequential(layers)
    model.compile(optimizer='adam', loss='mse')
    return model
# Out:
# Using TensorFlow backend.

# %%
from keras.callbacks import ModelCheckpoint
from keras.callbacks import EarlyStopping
from keras.models import load_model
# ten fold
from sklearn.model_selection import KFold
kfold = KFold(n_splits=5, shuffle=True)
from keras.models import load_model
from datetime import datetime
# import tensorflowjs as tfjs

sequenceSteps = 100

msescores = []
model_config = "config_8_8_8_4_ts"+str(sequenceSteps)

tempAllVariables = ['arrTemperature0', 'arrTemperature1', 'arrTemperature2', 'arrCPU_load0', 'arrMemory_usage0', 'arrFans_health0', 'arrFans_health1', 'arrFans_health2', 'arrFans_health3', 'arrPower_usage0']
allVariables = ['arrPower_usage0']
timeList = []



for feature in allVariables:
    print(feature)
    X_train, X_test, y_train, Y_test = splitTrainTest(feature)

    for training_time in range(0,3):
        start_time = datetime.now()
        print(start_time)

        counter= 0
        for trainIdx, testIdx in kfold.split(X_train, y_train):
            # create callbacks
            model_path = feature+'_training_time_'+str(training_time)+'_best_model_fold_'+str(counter)+"_"+model_config+'.h5'
            mc = ModelCheckpoint('newModel/'+model_path, monitor='val_loss', mode='min', verbose=1, save_best_only=True)
            es = EarlyStopping(monitor='val_loss', min_delta=0, patience=3, verbose=1)
            # create model
            model = createModel(l1Nodes = 8, l2Nodes = 8, d1Nodes = 8, d2Nodes = 4, inputShape= (X_train.shape[1], X_train.shape[2]))
            model.fit(X_train[trainIdx], y_train[trainIdx], validation_data=(X_train[testIdx], y_train[testIdx]), batch_size=32, epochs=40, callbacks=[mc, es])
            # Done load the best model of this fold
            saved_model = load_model('newModel/'+model_path)
            msescores.append({'path': 'newModel/'+model_path, 'mse': saved_model.evaluate(X_train[testIdx], y_train[testIdx])})
            counter = counter + 1
        
#             tfjs.converters.save_keras_model(saved_model, 'newModel/'+model_path)

        end_time = datetime.now()
    
        timeList.append({'start': start_time, 'end': end_time, 'time': datetime.timestamp(end_time)-datetime.timestamp(start_time)})
# Out:
# arrFans_health3
# 2019-11-03 09:46:51.767594
# Train on 249 samples, validate on 63 samples
# Epoch 1/40
# 249/249 [==============================] - 4s 17ms/step - loss: 84543954.5703 - val_loss: 86391022.6032
#
# Epoch 00001: val_loss improved from inf to 86391022.60317, saving model to newModel/arrFans_health3_training_time_0_best_model_fold_0_config_8_8_8_4_ts100.h5
# Epoch 2/40
# 249/249 [==============================] - 0s 2ms/step - loss: 84526640.1928 - val_loss: 86368939.0476
#
# Epoch 00002: val_loss improved from 86391022.60317 to 86368939.04762, saving model to newModel/arrFans_health3_training_time_0_best_model_fold_0_config_8_8_8_4_ts100.h5
# Epoch 3/40
# 249/249 [==============================] - 0s 2ms/step - loss: 84499064.3213 - val_loss: 86335020.4444
#
# Epoch 00003: val_loss improved from 86368939.04762 to 86335020.44444, saving model to newModel/arrFans_health3_training_time_0_best_model_fold_0_config_8_8_8_4_ts100.h5
# Epoch 4/40
# 249/249 [==============================] - 0s 2ms/step - loss: 84456538.1847 - val_loss: 86283041.5238
#
# Epoch 00004: val_loss improved from 86335020.44444 to 86283041.52381, saving model to newModel/arrFans_health3_training_time_0_best_model_fold_0_config_8_8_8_4_ts100.h5
# Epoch 5/40
# 249/249 [==============================] - 0s 2ms/step - loss: 84390907.4056 - val_loss: 86204986.4127
#
# Epoch 00005: val_loss improved from 86283041.52381 to 86204986.41270, saving model to newModel/arrFans_health3_training_time_0_best_model_fold_0_config_8_8_8_4_ts100.h5
# Epoch 6/40
# 249/249 [==============================] - 0s 2ms/step - loss: 84292859.7269 - val_loss: 86091225.7778
#
# Epoch 00006: val_loss improved from 86204986.41270 to 86091225.77778, saving model to newModel/arrFans_health3_training_time_0_best_model_fold_0_config_8_8_8_4_ts100.h5
# Epoch 7/40
# 249/249 [==============================] - 0s 2ms/step - loss: 84150192.5462 - val_loss: 85930460.6984
#
# Epoch 00007: val_loss improved from 86091225.77778 to 85930460.69841, saving model to newModel/arrFans_health3_training_time_0_best_model_fold_0_config_8_8_8_4_ts100.h5
# Epoch 8/40
# 249/249 [==============================] - 0s 2ms/step - loss: 83947830.6185 - val_loss: 85705968.3810
#
# Epoch 00008: val_loss improved from 85930460.69841 to 85705968.38095, saving model to newModel/arrFans_health3_training_time_0_best_model_fold_0_config_8_8_8_4_ts100.h5
# Epoch 9/40
# 249/249 [==============================] - 0s 2ms/step - loss: 83673221.7189 - val_loss: 85369741.9683
#
# Epoch 00009: val_loss improved from 85705968.38095 to 85369741.96825, saving model to newModel/arrFans_health3_training_time_0_best_model_fold_0_config_8_8_8_4_ts100.h5
# Epoch 10/40
# 249/249 [==============================] - 0s 2ms/step - loss: 83286412.0161 - val_loss: 84899348.5714
#
# Epoch 00010: val_loss improved from 85369741.96825 to 84899348.57143, saving model to newModel/arrFans_health3_training_time_0_best_model_fold_0_config_8_8_8_4_ts100.h5
# Epoch 11/40
# 249/249 [==============================] - 0s 2ms/step - loss: 82729187.1165 - val_loss: 84141592.8889
#
# Epoch 00011: val_loss improved from 84899348.57143 to 84141592.88889, saving model to newModel/arrFans_health3_training_time_0_best_model_fold_0_config_8_8_8_4_ts100.h5
# Epoch 12/40
# 249/249 [==============================] - 0s 2ms/step - loss: 81944019.6305 - val_loss: 83292391.1111
#
# Epoch 00012: val_loss improved from 84141592.88889 to 83292391.11111, saving model to newModel/arrFans_health3_training_time_0_best_model_fold_0_config_8_8_8_4_ts100.h5
# Epoch 13/40
# 249/249 [==============================] - 0s 2ms/step - loss: 81081053.1727 - val_loss: 82339576.5079
#
# Epoch 00013: val_loss improved from 83292391.11111 to 82339576.50794, saving model to newModel/arrFans_health3_training_time_0_best_model_fold_0_config_8_8_8_4_ts100.h5
# Epoch 14/40
# 249/249 [==============================] - 0s 2ms/step - loss: 80039431.4538 - val_loss: 81136835.9365
#
# Epoch 00014: val_loss improved from 82339576.50794 to 81136835.93651, saving model to newModel/arrFans_health3_training_time_0_best_model_fold_0_config_8_8_8_4_ts100.h5
# Epoch 15/40
# 249/249 [==============================] - 0s 2ms/step - loss: 78786294.8594 - val_loss: 79759645.3333
#
# Epoch 00015: val_loss improved from 81136835.93651 to 79759645.33333, saving model to newModel/arrFans_health3_training_time_0_best_model_fold_0_config_8_8_8_4_ts100.h5
# Epoch 16/40
# 249/249 [==============================] - 0s 2ms/step - loss: 77357904.9960 - val_loss: 78237202.0317
#
# Epoch 00016: val_loss improved from 79759645.33333 to 78237202.03175, saving model to newModel/arrFans_health3_training_time_0_best_model_fold_0_config_8_8_8_4_ts100.h5
# Epoch 17/40
# 249/249 [==============================] - 0s 2ms/step - loss: 75785698.6024 - val_loss: 76566273.2698
#
# Epoch 00017: val_loss improved from 78237202.03175 to 76566273.26984, saving model to newModel/arrFans_health3_training_time_0_best_model_fold_0_config_8_8_8_4_ts100.h5
# Epoch 18/40
# 249/249 [==============================] - 0s 2ms/step - loss: 74081094.1044 - val_loss: 74757480.8889
#
# Epoch 00018: val_loss improved from 76566273.26984 to 74757480.88889, saving model to newModel/arrFans_health3_training_time_0_best_model_fold_0_config_8_8_8_4_ts100.h5
# Epoch 19/40
# 249/249 [==============================] - 0s 2ms/step - loss: 72235173.3012 - val_loss: 72828715.4286
#
# Epoch 00019: val_loss improved from 74757480.88889 to 72828715.42857, saving model to newModel/arrFans_health3_training_time_0_best_model_fold_0_config_8_8_8_4_ts100.h5
# Epoch 20/40
# 249/249 [==============================] - 0s 2ms/step - loss: 70276811.0201 - val_loss: 70786190.7302
#
# Epoch 00020: val_loss improved from 72828715.42857 to 70786190.73016, saving model to newModel/arrFans_health3_training_time_0_best_model_fold_0_config_8_8_8_4_ts100.h5
# Epoch 21/40
# 249/249 [==============================] - 0s 2ms/step - loss: 68221807.0040 - val_loss: 68637166.4762
#
# Epoch 00021: val_loss improved from 70786190.73016 to 68637166.47619, saving model to newModel/arrFans_health3_training_time_0_best_model_fold_0_config_8_8_8_4_ts100.h5
# Epoch 22/40
# 249/249 [==============================] - 0s 2ms/step - loss: 66061514.9719 - val_loss: 66401391.8730
#
# Epoch 00022: val_loss improved from 68637166.47619 to 66401391.87302, saving model to newModel/arrFans_health3_training_time_0_best_model_fold_0_config_8_8_8_4_ts100.h5
# Epoch 23/40
# 249/249 [==============================] - 0s 2ms/step - loss: 63823573.5422 - val_loss: 64084767.1111
#
# Epoch 00023: val_loss improved from 66401391.87302 to 64084767.11111, saving model to newModel/arrFans_health3_training_time_0_best_model_fold_0_config_8_8_8_4_ts100.h5
# Epoch 24/40
# 249/249 [==============================] - 0s 2ms/step - loss: 61512022.2329 - val_loss: 61696857.7778
#
# Epoch 00024: val_loss improved from 64084767.11111 to 61696857.77778, saving model to newModel/arrFans_health3_training_time_0_best_model_fold_0_config_8_8_8_4_ts100.h5
# Epoch 25/40
# 249/249 [==============================] - 0s 2ms/step - loss: 59117107.2610 - val_loss: 59257912.8254
#
# Epoch 00025: val_loss improved from 61696857.77778 to 59257912.82540, saving model to newModel/arrFans_health3_training_time_0_best_model_fold_0_config_8_8_8_4_ts100.h5
# Epoch 26/40
# 249/249 [==============================] - 0s 2ms/step - loss: 56699398.5221 - val_loss: 56749808.5714
#
# Epoch 00026: val_loss improved from 59257912.82540 to 56749808.57143, saving model to newModel/arrFans_health3_training_time_0_best_model_fold_0_config_8_8_8_4_ts100.h5
# Epoch 27/40
# 249/249 [==============================] - 0s 2ms/step - loss: 54199458.0723 - val_loss: 54207226.9206
#
# Epoch 00027: val_loss improved from 56749808.57143 to 54207226.92063, saving model to newModel/arrFans_health3_training_time_0_best_model_fold_0_config_8_8_8_4_ts100.h5
# Epoch 28/40
# 249/249 [==============================] - 0s 2ms/step - loss: 51686649.7510 - val_loss: 51620083.7460
#
# Epoch 00028: val_loss improved from 54207226.92063 to 51620083.74603, saving model to newModel/arrFans_health3_training_time_0_best_model_fold_0_config_8_8_8_4_ts100.h5
# Epoch 29/40
# 249/249 [==============================] - 0s 2ms/step - loss: 49119532.8996 - val_loss: 49017260.1905
#
# Epoch 00029: val_loss improved from 51620083.74603 to 49017260.19048, saving model to newModel/arrFans_health3_training_time_0_best_model_fold_0_config_8_8_8_4_ts100.h5
# Epoch 30/40
# 249/249 [==============================] - 0s 2ms/step - loss: 46539797.8474 - val_loss: 46398796.8889
#
# Epoch 00030: val_loss improved from 49017260.19048 to 46398796.88889, saving model to newModel/arrFans_health3_training_time_0_best_model_fold_0_config_8_8_8_4_ts100.h5
# Epoch 31/40
# 249/249 [==============================] - 0s 2ms/step - loss: 43965955.5181 - val_loss: 43765680.1905
#
# Epoch 00031: val_loss improved from 46398796.88889 to 43765680.19048, saving model to newModel/arrFans_health3_training_time_0_best_model_fold_0_config_8_8_8_4_ts100.h5
# Epoch 32/40
# 249/249 [==============================] - 0s 2ms/step - loss: 41372121.1084 - val_loss: 41147208.0635
#
# Epoch 00032: val_loss improved from 43765680.19048 to 41147208.06349, saving model to newModel/arrFans_health3_training_time_0_best_model_fold_0_config_8_8_8_4_ts100.h5
# Epoch 33/40
# 249/249 [==============================] - 0s 2ms/step - loss: 38814191.3414 - val_loss: 38547561.2063
#
# Epoch 00033: val_loss improved from 41147208.06349 to 38547561.20635, saving model to newModel/arrFans_health3_training_time_0_best_model_fold_0_config_8_8_8_4_ts100.h5
# Epoch 34/40
# 249/249 [==============================] - 0s 2ms/step - loss: 36266575.2932 - val_loss: 35989751.5556
#
# Epoch 00034: val_loss improved from 38547561.20635 to 35989751.55556, saving model to newModel/arrFans_health3_training_time_0_best_model_fold_0_config_8_8_8_4_ts100.h5
# Epoch 35/40
# 249/249 [==============================] - 0s 2ms/step - loss: 33769100.6506 - val_loss: 33479141.0159
#
# Epoch 00035: val_loss improved from 35989751.55556 to 33479141.01587, saving model to newModel/arrFans_health3_training_time_0_best_model_fold_0_config_8_8_8_4_ts100.h5
# Epoch 36/40
# 249/249 [==============================] - 0s 2ms/step - loss: 31324943.3173 - val_loss: 31025039.8413
#
# Epoch 00036: val_loss improved from 33479141.01587 to 31025039.84127, saving model to newModel/arrFans_health3_training_time_0_best_model_fold_0_config_8_8_8_4_ts100.h5
# Epoch 37/40
# 249/249 [==============================] - 0s 2ms/step - loss: 28953975.8876 - val_loss: 28631086.6032
#
# Epoch 00037: val_loss improved from 31025039.84127 to 28631086.60317, saving model to newModel/arrFans_health3_training_time_0_best_model_fold_0_config_8_8_8_4_ts100.h5
# Epoch 38/40
# 249/249 [==============================] - 0s 2ms/step - loss: 26646677.9759 - val_loss: 26315914.7937
#
# Epoch 00038: val_loss improved from 28631086.60317 to 26315914.79365, saving model to newModel/arrFans_health3_training_time_0_best_model_fold_0_config_8_8_8_4_ts100.h5
# Epoch 39/40
# 249/249 [==============================] - 0s 2ms/step - loss: 24408667.9438 - val_loss: 24101317.3651
#
# Epoch 00039: val_loss improved from 26315914.79365 to 24101317.36508, saving model to newModel/arrFans_health3_training_time_0_best_model_fold_0_config_8_8_8_4_ts100.h5
# Epoch 40/40
# 249/249 [==============================] - 0s 2ms/step - loss: 22297802.4096 - val_loss: 21971569.9365
#
# Epoch 00040: val_loss improved from 24101317.36508 to 21971569.93651, saving model to newModel/arrFans_health3_training_time_0_best_model_fold_0_config_8_8_8_4_ts100.h5
# 63/63 [==============================] - 2s 38ms/step
# Train on 249 samples, validate on 63 samples
# Epoch 1/40
# 249/249 [==============================] - 4s 18ms/step - loss: 86013888.4819 - val_loss: 80624102.2222
#
# Epoch 00001: val_loss improved from inf to 80624102.22222, saving model to newModel/arrFans_health3_training_time_0_best_model_fold_1_config_8_8_8_4_ts100.h5
# Epoch 2/40
# 249/249 [==============================] - 0s 2ms/step - loss: 86013837.1406 - val_loss: 80624026.1587
#
# Epoch 00002: val_loss improved from 80624102.22222 to 80624026.15873, saving model to newModel/arrFans_health3_training_time_0_best_model_fold_1_config_8_8_8_4_ts100.h5
# Epoch 3/40
# 249/249 [==============================] - 0s 2ms/step - loss: 86013440.8996 - val_loss: 80623125.3333
#
# Epoch 00003: val_loss improved from 80624026.15873 to 80623125.33333, saving model to newModel/arrFans_health3_training_time_0_best_model_fold_1_config_8_8_8_4_ts100.h5
# Epoch 4/40
# 249/249 [==============================] - 0s 2ms/step - loss: 86011807.0683 - val_loss: 80621454.9841
#
# Epoch 00004: val_loss improved from 80623125.33333 to 80621454.98413, saving model to newModel/arrFans_health3_training_time_0_best_model_fold_1_config_8_8_8_4_ts100.h5
# Epoch 5/40
# 249/249 [==============================] - 0s 2ms/step - loss: 86008785.3173 - val_loss: 80617360.5079
#
# Epoch 00005: val_loss improved from 80621454.98413 to 80617360.50794, saving model to newModel/arrFans_health3_training_time_0_best_model_fold_1_config_8_8_8_4_ts100.h5
# Epoch 6/40
# 249/249 [==============================] - 0s 2ms/step - loss: 86001900.8835 - val_loss: 80608179.0476
#
# Epoch 00006: val_loss improved from 80617360.50794 to 80608179.04762, saving model to newModel/arrFans_health3_training_time_0_best_model_fold_1_config_8_8_8_4_ts100.h5
# Epoch 7/40
# 249/249 [==============================] - 0s 2ms/step - loss: 85987785.9920 - val_loss: 80589020.3175
#
# Epoch 00007: val_loss improved from 80608179.04762 to 80589020.31746, saving model to newModel/arrFans_health3_training_time_0_best_model_fold_1_config_8_8_8_4_ts100.h5
# Epoch 8/40
# 249/249 [==============================] - 0s 2ms/step - loss: 85958657.7671 - val_loss: 80551967.1111
#
# Epoch 00008: val_loss improved from 80589020.31746 to 80551967.11111, saving model to newModel/arrFans_health3_training_time_0_best_model_fold_1_config_8_8_8_4_ts100.h5
# Epoch 9/40
# 249/249 [==============================] - 0s 2ms/step - loss: 85908143.4859 - val_loss: 80488258.7937
#
# Epoch 00009: val_loss improved from 80551967.11111 to 80488258.79365, saving model to newModel/arrFans_health3_training_time_0_best_model_fold_1_config_8_8_8_4_ts100.h5
# Epoch 10/40
# 249/249 [==============================] - 0s 2ms/step - loss: 85829936.4498 - val_loss: 80390606.4762
#
# Epoch 00010: val_loss improved from 80488258.79365 to 80390606.47619, saving model to newModel/arrFans_health3_training_time_0_best_model_fold_1_config_8_8_8_4_ts100.h5
# Epoch 11/40
# 249/249 [==============================] - 0s 2ms/step - loss: 85718618.0241 - val_loss: 80263776.7619
#
# Epoch 00011: val_loss improved from 80390606.47619 to 80263776.76190, saving model to newModel/arrFans_health3_training_time_0_best_model_fold_1_config_8_8_8_4_ts100.h5
# Epoch 12/40
# 249/249 [==============================] - 0s 2ms/step - loss: 85576834.8916 - val_loss: 80112726.6032
#
# Epoch 00012: val_loss improved from 80263776.76190 to 80112726.60317, saving model to newModel/arrFans_health3_training_time_0_best_model_fold_1_config_8_8_8_4_ts100.h5
# Epoch 13/40
# 249/249 [==============================] - 0s 2ms/step - loss: 85406367.2610 - val_loss: 79931747.8095
#
# Epoch 00013: val_loss improved from 80112726.60317 to 79931747.80952, saving model to newModel/arrFans_health3_training_time_0_best_model_fold_1_config_8_8_8_4_ts100.h5
# Epoch 14/40
# 249/249 [==============================] - 0s 2ms/step - loss: 85201923.4699 - val_loss: 79714017.0159
#
# Epoch 00014: val_loss improved from 79931747.80952 to 79714017.01587, saving model to newModel/arrFans_health3_training_time_0_best_model_fold_1_config_8_8_8_4_ts100.h5
# Epoch 15/40
# 249/249 [==============================] - 0s 2ms/step - loss: 84960712.8032 - val_loss: 79456424.3810
#
# Epoch 00015: val_loss improved from 79714017.01587 to 79456424.38095, saving model to newModel/arrFans_health3_training_time_0_best_model_fold_1_config_8_8_8_4_ts100.h5
# Epoch 16/40
# 249/249 [==============================] - 0s 2ms/step - loss: 84676983.6145 - val_loss: 79158406.3492
#
# Epoch 00016: val_loss improved from 79456424.38095 to 79158406.34921, saving model to newModel/arrFans_health3_training_time_0_best_model_fold_1_config_8_8_8_4_ts100.h5
# Epoch 17/40
# 249/249 [==============================] - 0s 2ms/step - loss: 84349677.5904 - val_loss: 78820888.8889
#
# Epoch 00017: val_loss improved from 79158406.34921 to 78820888.88889, saving model to newModel/arrFans_health3_training_time_0_best_model_fold_1_config_8_8_8_4_ts100.h5
# Epoch 18/40
# 249/249 [==============================] - 0s 2ms/step - loss: 83982909.0120 - val_loss: 78443896.0000
#
# Epoch 00018: val_loss improved from 78820888.88889 to 78443896.00000, saving model to newModel/arrFans_health3_training_time_0_best_model_fold_1_config_8_8_8_4_ts100.h5
# Epoch 19/40
# 249/249 [==============================] - 0s 2ms/step - loss: 83577068.0161 - val_loss: 78027924.8254
#
# Epoch 00019: val_loss improved from 78443896.00000 to 78027924.82540, saving model to newModel/arrFans_health3_training_time_0_best_model_fold_1_config_8_8_8_4_ts100.h5
# Epoch 20/40
# 249/249 [==============================] - 0s 2ms/step - loss: 83133347.8554 - val_loss: 77574611.0476
#
# Epoch 00020: val_loss improved from 78027924.82540 to 77574611.04762, saving model to newModel/arrFans_health3_training_time_0_best_model_fold_1_config_8_8_8_4_ts100.h5
# Epoch 21/40
# 249/249 [==============================] - 0s 2ms/step - loss: 82647366.2008 - val_loss: 77087217.6508
#
# Epoch 00021: val_loss improved from 77574611.04762 to 77087217.65079, saving model to newModel/arrFans_health3_training_time_0_best_model_fold_1_config_8_8_8_4_ts100.h5
# Epoch 22/40
# 249/249 [==============================] - 0s 2ms/step - loss: 82130214.4257 - val_loss: 76562869.9683
#
# Epoch 00022: val_loss improved from 77087217.65079 to 76562869.96825, saving model to newModel/arrFans_health3_training_time_0_best_model_fold_1_config_8_8_8_4_ts100.h5
# Epoch 23/40
# 249/249 [==============================] - 0s 2ms/step - loss: 81573567.6145 - val_loss: 76003596.4444
#
# Epoch 00023: val_loss improved from 76562869.96825 to 76003596.44444, saving model to newModel/arrFans_health3_training_time_0_best_model_fold_1_config_8_8_8_4_ts100.h5
# Epoch 24/40
# 249/249 [==============================] - 0s 2ms/step - loss: 80979209.9920 - val_loss: 75409694.7302
#
# Epoch 00024: val_loss improved from 76003596.44444 to 75409694.73016, saving model to newModel/arrFans_health3_training_time_0_best_model_fold_1_config_8_8_8_4_ts100.h5
# Epoch 25/40
# 249/249 [==============================] - 0s 2ms/step - loss: 80353114.4739 - val_loss: 74778588.6984
#
# Epoch 00025: val_loss improved from 75409694.73016 to 74778588.69841, saving model to newModel/arrFans_health3_training_time_0_best_model_fold_1_config_8_8_8_4_ts100.h5
# Epoch 26/40
# 249/249 [==============================] - 0s 2ms/step - loss: 79682623.3574 - val_loss: 74114433.2698
#
# Epoch 00026: val_loss improved from 74778588.69841 to 74114433.26984, saving model to newModel/arrFans_health3_training_time_0_best_model_fold_1_config_8_8_8_4_ts100.h5
# Epoch 27/40
# 249/249 [==============================] - 0s 2ms/step - loss: 78981923.7912 - val_loss: 73412686.8571
#
# Epoch 00027: val_loss improved from 74114433.26984 to 73412686.85714, saving model to newModel/arrFans_health3_training_time_0_best_model_fold_1_config_8_8_8_4_ts100.h5
# Epoch 28/40
# 249/249 [==============================] - 0s 2ms/step - loss: 78239890.9237 - val_loss: 72675595.8095
#
# Epoch 00028: val_loss improved from 73412686.85714 to 72675595.80952, saving model to newModel/arrFans_health3_training_time_0_best_model_fold_1_config_8_8_8_4_ts100.h5
# Epoch 29/40
# 249/249 [==============================] - 0s 2ms/step - loss: 77462823.1647 - val_loss: 71901460.1905
#
# Epoch 00029: val_loss improved from 72675595.80952 to 71901460.19048, saving model to newModel/arrFans_health3_training_time_0_best_model_fold_1_config_8_8_8_4_ts100.h5
# Epoch 30/40
# 249/249 [==============================] - 0s 2ms/step - loss: 76647463.7108 - val_loss: 71090666.0317
#
# Epoch 00030: val_loss improved from 71901460.19048 to 71090666.03175, saving model to newModel/arrFans_health3_training_time_0_best_model_fold_1_config_8_8_8_4_ts100.h5
# Epoch 31/40
# 249/249 [==============================] - 0s 2ms/step - loss: 75791488.1606 - val_loss: 70245286.7302
#
# Epoch 00031: val_loss improved from 71090666.03175 to 70245286.73016, saving model to newModel/arrFans_health3_training_time_0_best_model_fold_1_config_8_8_8_4_ts100.h5
# Epoch 32/40
# 249/249 [==============================] - 0s 2ms/step - loss: 74905982.3293 - val_loss: 69359754.9206
#
# Epoch 00032: val_loss improved from 70245286.73016 to 69359754.92063, saving model to newModel/arrFans_health3_training_time_0_best_model_fold_1_config_8_8_8_4_ts100.h5
# Epoch 33/40
# 249/249 [==============================] - 0s 2ms/step - loss: 73974158.1687 - val_loss: 68439701.9683
#
# Epoch 00033: val_loss improved from 69359754.92063 to 68439701.96825, saving model to newModel/arrFans_health3_training_time_0_best_model_fold_1_config_8_8_8_4_ts100.h5
# Epoch 34/40
# 249/249 [==============================] - 0s 2ms/step - loss: 73004769.7992 - val_loss: 67484641.6508
#
# Epoch 00034: val_loss improved from 68439701.96825 to 67484641.65079, saving model to newModel/arrFans_health3_training_time_0_best_model_fold_1_config_8_8_8_4_ts100.h5
# Epoch 35/40
# 249/249 [==============================] - 0s 2ms/step - loss: 71996450.4418 - val_loss: 66495127.6825
#
# Epoch 00035: val_loss improved from 67484641.65079 to 66495127.68254, saving model to newModel/arrFans_health3_training_time_0_best_model_fold_1_config_8_8_8_4_ts100.h5
# Epoch 36/40
# 249/249 [==============================] - 0s 2ms/step - loss: 70959158.2651 - val_loss: 65466265.7143
#
# Epoch 00036: val_loss improved from 66495127.68254 to 65466265.71429, saving model to newModel/arrFans_health3_training_time_0_best_model_fold_1_config_8_8_8_4_ts100.h5
# Epoch 37/40
# 249/249 [==============================] - 0s 2ms/step - loss: 69873911.0040 - val_loss: 64405991.8730
#
# Epoch 00037: val_loss improved from 65466265.71429 to 64405991.87302, saving model to newModel/arrFans_health3_training_time_0_best_model_fold_1_config_8_8_8_4_ts100.h5
# Epoch 38/40
# 249/249 [==============================] - 0s 2ms/step - loss: 68764652.0482 - val_loss: 63306453.3968
#
# Epoch 00038: val_loss improved from 64405991.87302 to 63306453.39683, saving model to newModel/arrFans_health3_training_time_0_best_model_fold_1_config_8_8_8_4_ts100.h5
# Epoch 39/40
# 249/249 [==============================] - 0s 2ms/step - loss: 67610944.6104 - val_loss: 62175109.2063
#
# Epoch 00039: val_loss improved from 63306453.39683 to 62175109.20635, saving model to newModel/arrFans_health3_training_time_0_best_model_fold_1_config_8_8_8_4_ts100.h5
# Epoch 40/40
# 249/249 [==============================] - 0s 2ms/step - loss: 66425888.8675 - val_loss: 61012857.7143
#
# Epoch 00040: val_loss improved from 62175109.20635 to 61012857.71429, saving model to newModel/arrFans_health3_training_time_0_best_model_fold_1_config_8_8_8_4_ts100.h5
# 63/63 [==============================] - 3s 42ms/step
# Train on 250 samples, validate on 62 samples
# Epoch 1/40
# 250/250 [==============================] - 5s 19ms/step - loss: 84902711.2960 - val_loss: 84913853.1613
#
# Epoch 00001: val_loss improved from inf to 84913853.16129, saving model to newModel/arrFans_health3_training_time_0_best_model_fold_2_config_8_8_8_4_ts100.h5
# Epoch 2/40
# 250/250 [==============================] - 0s 2ms/step - loss: 84856513.9200 - val_loss: 84863404.1290
#
# Epoch 00002: val_loss improved from 84913853.16129 to 84863404.12903, saving model to newModel/arrFans_health3_training_time_0_best_model_fold_2_config_8_8_8_4_ts100.h5
# Epoch 3/40
# 250/250 [==============================] - 0s 2ms/step - loss: 84756676.6720 - val_loss: 84766649.0323
#
# Epoch 00003: val_loss improved from 84863404.12903 to 84766649.03226, saving model to newModel/arrFans_health3_training_time_0_best_model_fold_2_config_8_8_8_4_ts100.h5
# Epoch 4/40
# 250/250 [==============================] - 0s 2ms/step - loss: 84587619.6480 - val_loss: 84596939.8710
#
# Epoch 00004: val_loss improved from 84766649.03226 to 84596939.87097, saving model to newModel/arrFans_health3_training_time_0_best_model_fold_2_config_8_8_8_4_ts100.h5
# Epoch 5/40
# 250/250 [==============================] - 0s 2ms/step - loss: 84310496.2560 - val_loss: 84335641.5484
#
# Epoch 00005: val_loss improved from 84596939.87097 to 84335641.54839, saving model to newModel/arrFans_health3_training_time_0_best_model_fold_2_config_8_8_8_4_ts100.h5
# Epoch 6/40
# 250/250 [==============================] - 0s 2ms/step - loss: 83910116.0320 - val_loss: 83973070.4516
#
# Epoch 00006: val_loss improved from 84335641.54839 to 83973070.45161, saving model to newModel/arrFans_health3_training_time_0_best_model_fold_2_config_8_8_8_4_ts100.h5
# Epoch 7/40
# 250/250 [==============================] - 0s 2ms/step - loss: 83386939.0080 - val_loss: 83483902.7097
#
# Epoch 00007: val_loss improved from 83973070.45161 to 83483902.70968, saving model to newModel/arrFans_health3_training_time_0_best_model_fold_2_config_8_8_8_4_ts100.h5
# Epoch 8/40
# 250/250 [==============================] - 0s 2ms/step - loss: 82713228.9920 - val_loss: 82852373.9355
#
# Epoch 00008: val_loss improved from 83483902.70968 to 82852373.93548, saving model to newModel/arrFans_health3_training_time_0_best_model_fold_2_config_8_8_8_4_ts100.h5
# Epoch 9/40
# 250/250 [==============================] - 0s 2ms/step - loss: 81863842.0480 - val_loss: 82046567.4839
#
# Epoch 00009: val_loss improved from 82852373.93548 to 82046567.48387, saving model to newModel/arrFans_health3_training_time_0_best_model_fold_2_config_8_8_8_4_ts100.h5
# Epoch 10/40
# 250/250 [==============================] - 0s 2ms/step - loss: 80603735.6800 - val_loss: 80630102.1935
#
# Epoch 00010: val_loss improved from 82046567.48387 to 80630102.19355, saving model to newModel/arrFans_health3_training_time_0_best_model_fold_2_config_8_8_8_4_ts100.h5
# Epoch 11/40
# 250/250 [==============================] - 0s 2ms/step - loss: 78759257.4720 - val_loss: 78097585.2903
#
# Epoch 00011: val_loss improved from 80630102.19355 to 78097585.29032, saving model to newModel/arrFans_health3_training_time_0_best_model_fold_2_config_8_8_8_4_ts100.h5
# Epoch 12/40
# 250/250 [==============================] - 0s 2ms/step - loss: 76983513.0240 - val_loss: 76265822.9677
#
# Epoch 00012: val_loss improved from 78097585.29032 to 76265822.96774, saving model to newModel/arrFans_health3_training_time_0_best_model_fold_2_config_8_8_8_4_ts100.h5
# Epoch 13/40
# 250/250 [==============================] - 0s 2ms/step - loss: 75218718.0800 - val_loss: 74406682.0645
#
# Epoch 00013: val_loss improved from 76265822.96774 to 74406682.06452, saving model to newModel/arrFans_health3_training_time_0_best_model_fold_2_config_8_8_8_4_ts100.h5
# Epoch 14/40
# 250/250 [==============================] - 0s 2ms/step - loss: 73278403.1360 - val_loss: 72397073.2903
#
# Epoch 00014: val_loss improved from 74406682.06452 to 72397073.29032, saving model to newModel/arrFans_health3_training_time_0_best_model_fold_2_config_8_8_8_4_ts100.h5
# Epoch 15/40
# 250/250 [==============================] - 0s 2ms/step - loss: 71186678.3360 - val_loss: 70232607.7419
#
# Epoch 00015: val_loss improved from 72397073.29032 to 70232607.74194, saving model to newModel/arrFans_health3_training_time_0_best_model_fold_2_config_8_8_8_4_ts100.h5
# Epoch 16/40
# 250/250 [==============================] - 0s 2ms/step - loss: 68948574.3040 - val_loss: 67919817.0323
#
# Epoch 00016: val_loss improved from 70232607.74194 to 67919817.03226, saving model to newModel/arrFans_health3_training_time_0_best_model_fold_2_config_8_8_8_4_ts100.h5
# Epoch 17/40
# 250/250 [==============================] - 0s 2ms/step - loss: 66564021.2800 - val_loss: 65482612.1290
#
# Epoch 00017: val_loss improved from 67919817.03226 to 65482612.12903, saving model to newModel/arrFans_health3_training_time_0_best_model_fold_2_config_8_8_8_4_ts100.h5
# Epoch 18/40
# 250/250 [==============================] - 0s 2ms/step - loss: 64078887.9680 - val_loss: 62923037.4194
#
# Epoch 00018: val_loss improved from 65482612.12903 to 62923037.41935, saving model to newModel/arrFans_health3_training_time_0_best_model_fold_2_config_8_8_8_4_ts100.h5
# Epoch 19/40
# 250/250 [==============================] - 0s 2ms/step - loss: 61479906.3040 - val_loss: 60271088.7742
#
# Epoch 00019: val_loss improved from 62923037.41935 to 60271088.77419, saving model to newModel/arrFans_health3_training_time_0_best_model_fold_2_config_8_8_8_4_ts100.h5
# Epoch 20/40
# 250/250 [==============================] - 0s 2ms/step - loss: 58827921.0240 - val_loss: 57528011.4839
#
# Epoch 00020: val_loss improved from 60271088.77419 to 57528011.48387, saving model to newModel/arrFans_health3_training_time_0_best_model_fold_2_config_8_8_8_4_ts100.h5
# Epoch 21/40
# 250/250 [==============================] - 0s 2ms/step - loss: 56075085.7280 - val_loss: 54726678.5806
#
# Epoch 00021: val_loss improved from 57528011.48387 to 54726678.58065, saving model to newModel/arrFans_health3_training_time_0_best_model_fold_2_config_8_8_8_4_ts100.h5
# Epoch 22/40
# 250/250 [==============================] - 0s 2ms/step - loss: 53286072.3840 - val_loss: 51872722.3226
#
# Epoch 00022: val_loss improved from 54726678.58065 to 51872722.32258, saving model to newModel/arrFans_health3_training_time_0_best_model_fold_2_config_8_8_8_4_ts100.h5
# Epoch 23/40
# 250/250 [==============================] - 0s 2ms/step - loss: 50468438.7200 - val_loss: 48957764.3871
#
# Epoch 00023: val_loss improved from 51872722.32258 to 48957764.38710, saving model to newModel/arrFans_health3_training_time_0_best_model_fold_2_config_8_8_8_4_ts100.h5
# Epoch 24/40
# 250/250 [==============================] - 0s 2ms/step - loss: 47627625.8880 - val_loss: 46050756.9032
#
# Epoch 00024: val_loss improved from 48957764.38710 to 46050756.90323, saving model to newModel/arrFans_health3_training_time_0_best_model_fold_2_config_8_8_8_4_ts100.h5
# Epoch 25/40
# 250/250 [==============================] - 0s 2ms/step - loss: 44760337.1840 - val_loss: 43150274.4516
#
# Epoch 00025: val_loss improved from 46050756.90323 to 43150274.45161, saving model to newModel/arrFans_health3_training_time_0_best_model_fold_2_config_8_8_8_4_ts100.h5
# Epoch 26/40
# 250/250 [==============================] - 0s 2ms/step - loss: 41930022.1760 - val_loss: 40257883.0968
#
# Epoch 00026: val_loss improved from 43150274.45161 to 40257883.09677, saving model to newModel/arrFans_health3_training_time_0_best_model_fold_2_config_8_8_8_4_ts100.h5
# Epoch 27/40
# 250/250 [==============================] - 0s 2ms/step - loss: 39098516.1920 - val_loss: 37402011.8710
#
# Epoch 00027: val_loss improved from 40257883.09677 to 37402011.87097, saving model to newModel/arrFans_health3_training_time_0_best_model_fold_2_config_8_8_8_4_ts100.h5
# Epoch 28/40
# 250/250 [==============================] - 0s 2ms/step - loss: 36328917.3120 - val_loss: 34576212.2581
#
# Epoch 00028: val_loss improved from 37402011.87097 to 34576212.25806, saving model to newModel/arrFans_health3_training_time_0_best_model_fold_2_config_8_8_8_4_ts100.h5
# Epoch 29/40
# 250/250 [==============================] - 0s 2ms/step - loss: 33580708.9600 - val_loss: 31823622.3226
#
# Epoch 00029: val_loss improved from 34576212.25806 to 31823622.32258, saving model to newModel/arrFans_health3_training_time_0_best_model_fold_2_config_8_8_8_4_ts100.h5
# Epoch 30/40
# 250/250 [==============================] - 0s 2ms/step - loss: 30891952.8960 - val_loss: 29170052.9032
#
# Epoch 00030: val_loss improved from 31823622.32258 to 29170052.90323, saving model to newModel/arrFans_health3_training_time_0_best_model_fold_2_config_8_8_8_4_ts100.h5
# Epoch 31/40
# 250/250 [==============================] - 0s 2ms/step - loss: 28326438.2080 - val_loss: 26602566.2581
#
# Epoch 00031: val_loss improved from 29170052.90323 to 26602566.25806, saving model to newModel/arrFans_health3_training_time_0_best_model_fold_2_config_8_8_8_4_ts100.h5
# Epoch 32/40
# 250/250 [==============================] - 0s 2ms/step - loss: 25845206.9920 - val_loss: 24143440.9677
#
# Epoch 00032: val_loss improved from 26602566.25806 to 24143440.96774, saving model to newModel/arrFans_health3_training_time_0_best_model_fold_2_config_8_8_8_4_ts100.h5
# Epoch 33/40
# 250/250 [==============================] - 0s 2ms/step - loss: 23486234.8800 - val_loss: 21795103.1613
#
# Epoch 00033: val_loss improved from 24143440.96774 to 21795103.16129, saving model to newModel/arrFans_health3_training_time_0_best_model_fold_2_config_8_8_8_4_ts100.h5
# Epoch 34/40
# 250/250 [==============================] - 0s 2ms/step - loss: 21220338.1920 - val_loss: 19588630.3226
#
# Epoch 00034: val_loss improved from 21795103.16129 to 19588630.32258, saving model to newModel/arrFans_health3_training_time_0_best_model_fold_2_config_8_8_8_4_ts100.h5
# Epoch 35/40
# 250/250 [==============================] - 0s 2ms/step - loss: 19113696.8080 - val_loss: 17507971.3548
#
# Epoch 00035: val_loss improved from 19588630.32258 to 17507971.35484, saving model to newModel/arrFans_health3_training_time_0_best_model_fold_2_config_8_8_8_4_ts100.h5
# Epoch 36/40
# 250/250 [==============================] - 0s 2ms/step - loss: 17121872.0080 - val_loss: 15572854.5806
#
# Epoch 00036: val_loss improved from 17507971.35484 to 15572854.58065, saving model to newModel/arrFans_health3_training_time_0_best_model_fold_2_config_8_8_8_4_ts100.h5
# Epoch 37/40
# 250/250 [==============================] - 0s 2ms/step - loss: 15286681.4960 - val_loss: 13774041.9677
#
# Epoch 00037: val_loss improved from 15572854.58065 to 13774041.96774, saving model to newModel/arrFans_health3_training_time_0_best_model_fold_2_config_8_8_8_4_ts100.h5
# Epoch 38/40
# 250/250 [==============================] - 0s 2ms/step - loss: 13576477.8880 - val_loss: 12127739.7419
#
# Epoch 00038: val_loss improved from 13774041.96774 to 12127739.74194, saving model to newModel/arrFans_health3_training_time_0_best_model_fold_2_config_8_8_8_4_ts100.h5
# Epoch 39/40
# 250/250 [==============================] - 0s 2ms/step - loss: 12035670.1120 - val_loss: 10615901.0645
#
# Epoch 00039: val_loss improved from 12127739.74194 to 10615901.06452, saving model to newModel/arrFans_health3_training_time_0_best_model_fold_2_config_8_8_8_4_ts100.h5
# Epoch 40/40
# 250/250 [==============================] - 0s 2ms/step - loss: 10618819.0000 - val_loss: 9258161.0968
#
# Epoch 00040: val_loss improved from 10615901.06452 to 9258161.09677, saving model to newModel/arrFans_health3_training_time_0_best_model_fold_2_config_8_8_8_4_ts100.h5
# 62/62 [==============================] - 3s 46ms/step
# Train on 250 samples, validate on 62 samples
# Epoch 1/40
# 250/250 [==============================] - 5s 20ms/step - loss: 83921388.9280 - val_loss: 88956345.0323
#
# Epoch 00001: val_loss improved from inf to 88956345.03226, saving model to newModel/arrFans_health3_training_time_0_best_model_fold_3_config_8_8_8_4_ts100.h5
# Epoch 2/40
# 250/250 [==============================] - 0s 2ms/step - loss: 83913366.2720 - val_loss: 88943431.7419
#
# Epoch 00002: val_loss improved from 88956345.03226 to 88943431.74194, saving model to newModel/arrFans_health3_training_time_0_best_model_fold_3_config_8_8_8_4_ts100.h5
# Epoch 3/40
# 250/250 [==============================] - 0s 2ms/step - loss: 83898211.4560 - val_loss: 88919711.4839
#
# Epoch 00003: val_loss improved from 88943431.74194 to 88919711.48387, saving model to newModel/arrFans_health3_training_time_0_best_model_fold_3_config_8_8_8_4_ts100.h5
# Epoch 4/40
# 250/250 [==============================] - 0s 2ms/step - loss: 83872592.5120 - val_loss: 88879882.8387
#
# Epoch 00004: val_loss improved from 88919711.48387 to 88879882.83871, saving model to newModel/arrFans_health3_training_time_0_best_model_fold_3_config_8_8_8_4_ts100.h5
# Epoch 5/40
# 250/250 [==============================] - 0s 2ms/step - loss: 83829438.0800 - val_loss: 88817615.7419
#
# Epoch 00005: val_loss improved from 88879882.83871 to 88817615.74194, saving model to newModel/arrFans_health3_training_time_0_best_model_fold_3_config_8_8_8_4_ts100.h5
# Epoch 6/40
# 250/250 [==============================] - 0s 2ms/step - loss: 83766086.9760 - val_loss: 88730446.4516
#
# Epoch 00006: val_loss improved from 88817615.74194 to 88730446.45161, saving model to newModel/arrFans_health3_training_time_0_best_model_fold_3_config_8_8_8_4_ts100.h5
# Epoch 7/40
# 250/250 [==============================] - 0s 2ms/step - loss: 83678346.4960 - val_loss: 88619427.8710
#
# Epoch 00007: val_loss improved from 88730446.45161 to 88619427.87097, saving model to newModel/arrFans_health3_training_time_0_best_model_fold_3_config_8_8_8_4_ts100.h5
# Epoch 8/40
# 250/250 [==============================] - 0s 2ms/step - loss: 83568929.5360 - val_loss: 88477330.8387
#
# Epoch 00008: val_loss improved from 88619427.87097 to 88477330.83871, saving model to newModel/arrFans_health3_training_time_0_best_model_fold_3_config_8_8_8_4_ts100.h5
# Epoch 9/40
# 250/250 [==============================] - 0s 2ms/step - loss: 83430752.3840 - val_loss: 88300885.6774
#
# Epoch 00009: val_loss improved from 88477330.83871 to 88300885.67742, saving model to newModel/arrFans_health3_training_time_0_best_model_fold_3_config_8_8_8_4_ts100.h5
# Epoch 10/40
# 250/250 [==============================] - 0s 2ms/step - loss: 83258041.6000 - val_loss: 88085581.4194
#
# Epoch 00010: val_loss improved from 88300885.67742 to 88085581.41935, saving model to newModel/arrFans_health3_training_time_0_best_model_fold_3_config_8_8_8_4_ts100.h5
# Epoch 11/40
# 250/250 [==============================] - 0s 2ms/step - loss: 83047136.0000 - val_loss: 87822617.5484
#
# Epoch 00011: val_loss improved from 88085581.41935 to 87822617.54839, saving model to newModel/arrFans_health3_training_time_0_best_model_fold_3_config_8_8_8_4_ts100.h5
# Epoch 12/40
# 250/250 [==============================] - 0s 2ms/step - loss: 82799432.8960 - val_loss: 87504209.8065
#
# Epoch 00012: val_loss improved from 87822617.54839 to 87504209.80645, saving model to newModel/arrFans_health3_training_time_0_best_model_fold_3_config_8_8_8_4_ts100.h5
# Epoch 13/40
# 250/250 [==============================] - 0s 2ms/step - loss: 82493627.1360 - val_loss: 87131623.2258
#
# Epoch 00013: val_loss improved from 87504209.80645 to 87131623.22581, saving model to newModel/arrFans_health3_training_time_0_best_model_fold_3_config_8_8_8_4_ts100.h5
# Epoch 14/40
# 250/250 [==============================] - 0s 2ms/step - loss: 82114699.5840 - val_loss: 86641863.4839
#
# Epoch 00014: val_loss improved from 87131623.22581 to 86641863.48387, saving model to newModel/arrFans_health3_training_time_0_best_model_fold_3_config_8_8_8_4_ts100.h5
# Epoch 15/40
# 250/250 [==============================] - 0s 2ms/step - loss: 81671035.2000 - val_loss: 86062088.0000
#
# Epoch 00015: val_loss improved from 86641863.48387 to 86062088.00000, saving model to newModel/arrFans_health3_training_time_0_best_model_fold_3_config_8_8_8_4_ts100.h5
# Epoch 16/40
# 250/250 [==============================] - 0s 2ms/step - loss: 81223408.9600 - val_loss: 85478158.7097
#
# Epoch 00016: val_loss improved from 86062088.00000 to 85478158.70968, saving model to newModel/arrFans_health3_training_time_0_best_model_fold_3_config_8_8_8_4_ts100.h5
# Epoch 17/40
# 250/250 [==============================] - 0s 2ms/step - loss: 80662946.1760 - val_loss: 84835173.6774
#
# Epoch 00017: val_loss improved from 85478158.70968 to 84835173.67742, saving model to newModel/arrFans_health3_training_time_0_best_model_fold_3_config_8_8_8_4_ts100.h5
# Epoch 18/40
# 250/250 [==============================] - 0s 2ms/step - loss: 80060796.8000 - val_loss: 83927626.0645
#
# Epoch 00018: val_loss improved from 84835173.67742 to 83927626.06452, saving model to newModel/arrFans_health3_training_time_0_best_model_fold_3_config_8_8_8_4_ts100.h5
# Epoch 19/40
# 250/250 [==============================] - 0s 2ms/step - loss: 78856035.3280 - val_loss: 82286306.5806
#
# Epoch 00019: val_loss improved from 83927626.06452 to 82286306.58065, saving model to newModel/arrFans_health3_training_time_0_best_model_fold_3_config_8_8_8_4_ts100.h5
# Epoch 20/40
# 250/250 [==============================] - 0s 2ms/step - loss: 76821241.7280 - val_loss: 80501472.5161
#
# Epoch 00020: val_loss improved from 82286306.58065 to 80501472.51613, saving model to newModel/arrFans_health3_training_time_0_best_model_fold_3_config_8_8_8_4_ts100.h5
# Epoch 21/40
# 250/250 [==============================] - 0s 2ms/step - loss: 75270811.2640 - val_loss: 79087416.7742
#
# Epoch 00021: val_loss improved from 80501472.51613 to 79087416.77419, saving model to newModel/arrFans_health3_training_time_0_best_model_fold_3_config_8_8_8_4_ts100.h5
# Epoch 22/40
# 250/250 [==============================] - 0s 2ms/step - loss: 73867095.9360 - val_loss: 77572827.8710
#
# Epoch 00022: val_loss improved from 79087416.77419 to 77572827.87097, saving model to newModel/arrFans_health3_training_time_0_best_model_fold_3_config_8_8_8_4_ts100.h5
# Epoch 23/40
# 250/250 [==============================] - 0s 2ms/step - loss: 72323097.9200 - val_loss: 75970591.2258
#
# Epoch 00023: val_loss improved from 77572827.87097 to 75970591.22581, saving model to newModel/arrFans_health3_training_time_0_best_model_fold_3_config_8_8_8_4_ts100.h5
# Epoch 24/40
# 250/250 [==============================] - 0s 2ms/step - loss: 70727486.2720 - val_loss: 74291227.0968
#
# Epoch 00024: val_loss improved from 75970591.22581 to 74291227.09677, saving model to newModel/arrFans_health3_training_time_0_best_model_fold_3_config_8_8_8_4_ts100.h5
# Epoch 25/40
# 250/250 [==============================] - 0s 2ms/step - loss: 69067397.5680 - val_loss: 72537087.2258
#
# Epoch 00025: val_loss improved from 74291227.09677 to 72537087.22581, saving model to newModel/arrFans_health3_training_time_0_best_model_fold_3_config_8_8_8_4_ts100.h5
# Epoch 26/40
# 250/250 [==============================] - 0s 2ms/step - loss: 67296248.4480 - val_loss: 70713305.5484
#
# Epoch 00026: val_loss improved from 72537087.22581 to 70713305.54839, saving model to newModel/arrFans_health3_training_time_0_best_model_fold_3_config_8_8_8_4_ts100.h5
# Epoch 27/40
# 250/250 [==============================] - 0s 2ms/step - loss: 65483756.9920 - val_loss: 68805221.9355
#
# Epoch 00027: val_loss improved from 70713305.54839 to 68805221.93548, saving model to newModel/arrFans_health3_training_time_0_best_model_fold_3_config_8_8_8_4_ts100.h5
# Epoch 28/40
# 250/250 [==============================] - 0s 2ms/step - loss: 63595083.3920 - val_loss: 66836991.7419
#
# Epoch 00028: val_loss improved from 68805221.93548 to 66836991.74194, saving model to newModel/arrFans_health3_training_time_0_best_model_fold_3_config_8_8_8_4_ts100.h5
# Epoch 29/40
# 250/250 [==============================] - 0s 2ms/step - loss: 61660115.3920 - val_loss: 64802384.5161
#
# Epoch 00029: val_loss improved from 66836991.74194 to 64802384.51613, saving model to newModel/arrFans_health3_training_time_0_best_model_fold_3_config_8_8_8_4_ts100.h5
# Epoch 30/40
# 250/250 [==============================] - 0s 2ms/step - loss: 59675415.7120 - val_loss: 62701229.2903
#
# Epoch 00030: val_loss improved from 64802384.51613 to 62701229.29032, saving model to newModel/arrFans_health3_training_time_0_best_model_fold_3_config_8_8_8_4_ts100.h5
# Epoch 31/40
# 250/250 [==============================] - 0s 2ms/step - loss: 57599111.4880 - val_loss: 60563796.0000
#
# Epoch 00031: val_loss improved from 62701229.29032 to 60563796.00000, saving model to newModel/arrFans_health3_training_time_0_best_model_fold_3_config_8_8_8_4_ts100.h5
# Epoch 32/40
# 250/250 [==============================] - 0s 2ms/step - loss: 55502369.8560 - val_loss: 58372301.6774
#
# Epoch 00032: val_loss improved from 60563796.00000 to 58372301.67742, saving model to newModel/arrFans_health3_training_time_0_best_model_fold_3_config_8_8_8_4_ts100.h5
# Epoch 33/40
# 250/250 [==============================] - 0s 2ms/step - loss: 53363788.8320 - val_loss: 56130831.4839
#
# Epoch 00033: val_loss improved from 58372301.67742 to 56130831.48387, saving model to newModel/arrFans_health3_training_time_0_best_model_fold_3_config_8_8_8_4_ts100.h5
# Epoch 34/40
# 250/250 [==============================] - 0s 2ms/step - loss: 51188031.7760 - val_loss: 53848283.6129
#
# Epoch 00034: val_loss improved from 56130831.48387 to 53848283.61290, saving model to newModel/arrFans_health3_training_time_0_best_model_fold_3_config_8_8_8_4_ts100.h5
# Epoch 35/40
# 250/250 [==============================] - 0s 2ms/step - loss: 48967845.1200 - val_loss: 51542302.1935
#
# Epoch 00035: val_loss improved from 53848283.61290 to 51542302.19355, saving model to newModel/arrFans_health3_training_time_0_best_model_fold_3_config_8_8_8_4_ts100.h5
# Epoch 36/40
# 250/250 [==============================] - 0s 2ms/step - loss: 46720365.5360 - val_loss: 49222349.9355
#
# Epoch 00036: val_loss improved from 51542302.19355 to 49222349.93548, saving model to newModel/arrFans_health3_training_time_0_best_model_fold_3_config_8_8_8_4_ts100.h5
# Epoch 37/40
# 250/250 [==============================] - 0s 2ms/step - loss: 44483464.7360 - val_loss: 46875506.8387
#
# Epoch 00037: val_loss improved from 49222349.93548 to 46875506.83871, saving model to newModel/arrFans_health3_training_time_0_best_model_fold_3_config_8_8_8_4_ts100.h5
# Epoch 38/40
# 250/250 [==============================] - 0s 2ms/step - loss: 42214197.1200 - val_loss: 44529780.1290
#
# Epoch 00038: val_loss improved from 46875506.83871 to 44529780.12903, saving model to newModel/arrFans_health3_training_time_0_best_model_fold_3_config_8_8_8_4_ts100.h5
# Epoch 39/40
# 250/250 [==============================] - 0s 2ms/step - loss: 39944648.5440 - val_loss: 42190243.7419
#
# Epoch 00039: val_loss improved from 44529780.12903 to 42190243.74194, saving model to newModel/arrFans_health3_training_time_0_best_model_fold_3_config_8_8_8_4_ts100.h5
# Epoch 40/40
# 250/250 [==============================] - 0s 2ms/step - loss: 37702326.7520 - val_loss: 39854844.0000
#
# Epoch 00040: val_loss improved from 42190243.74194 to 39854844.00000, saving model to newModel/arrFans_health3_training_time_0_best_model_fold_3_config_8_8_8_4_ts100.h5
# 62/62 [==============================] - 3s 47ms/step
# Train on 250 samples, validate on 62 samples
# Epoch 1/40
# 250/250 [==============================] - 5s 20ms/step - loss: 85217764.6720 - val_loss: 83728758.4516
#
# Epoch 00001: val_loss improved from inf to 83728758.45161, saving model to newModel/arrFans_health3_training_time_0_best_model_fold_4_config_8_8_8_4_ts100.h5
# Epoch 2/40
# 250/250 [==============================] - 0s 2ms/step - loss: 85206683.4560 - val_loss: 83711678.9677
#
# Epoch 00002: val_loss improved from 83728758.45161 to 83711678.96774, saving model to newModel/arrFans_health3_training_time_0_best_model_fold_4_config_8_8_8_4_ts100.h5
# Epoch 3/40
# 250/250 [==============================] - 0s 2ms/step - loss: 85185999.7440 - val_loss: 83676376.5161
#
# Epoch 00003: val_loss improved from 83711678.96774 to 83676376.51613, saving model to newModel/arrFans_health3_training_time_0_best_model_fold_4_config_8_8_8_4_ts100.h5
# Epoch 4/40
# 250/250 [==============================] - 0s 2ms/step - loss: 85143596.2240 - val_loss: 83614286.9677
#
# Epoch 00004: val_loss improved from 83676376.51613 to 83614286.96774, saving model to newModel/arrFans_health3_training_time_0_best_model_fold_4_config_8_8_8_4_ts100.h5
# Epoch 5/40
# 250/250 [==============================] - 0s 2ms/step - loss: 85070243.4560 - val_loss: 83509635.0968
#
# Epoch 00005: val_loss improved from 83614286.96774 to 83509635.09677, saving model to newModel/arrFans_health3_training_time_0_best_model_fold_4_config_8_8_8_4_ts100.h5
# Epoch 6/40
# 250/250 [==============================] - 0s 2ms/step - loss: 84952387.8400 - val_loss: 83340070.1935
#
# Epoch 00006: val_loss improved from 83509635.09677 to 83340070.19355, saving model to newModel/arrFans_health3_training_time_0_best_model_fold_4_config_8_8_8_4_ts100.h5
# Epoch 7/40
# 250/250 [==============================] - 0s 2ms/step - loss: 84769426.7520 - val_loss: 83107612.6452
#
# Epoch 00007: val_loss improved from 83340070.19355 to 83107612.64516, saving model to newModel/arrFans_health3_training_time_0_best_model_fold_4_config_8_8_8_4_ts100.h5
# Epoch 8/40
# ...
#
# Epoch 00025: val_loss improved from 62502444.51613 to 60212890.32258, saving model to newModel/arrFans_health3_training_time_2_best_model_fold_3_config_8_8_8_4_ts100.h5
# Epoch 26/40
# 250/250 [==============================] - 0s 2ms/step - loss: 56227551.0400 - val_loss: 57874388.2581
#
# Epoch 00026: val_loss improved from 60212890.32258 to 57874388.25806, saving model to newModel/arrFans_health3_training_time_2_best_model_fold_3_config_8_8_8_4_ts100.h5
# Epoch 27/40
# 250/250 [==============================] - 0s 2ms/step - loss: 53915939.9680 - val_loss: 55488753.8065
#
# Epoch 00027: val_loss improved from 57874388.25806 to 55488753.80645, saving model to newModel/arrFans_health3_training_time_2_best_model_fold_3_config_8_8_8_4_ts100.h5
# Epoch 28/40
# 250/250 [==============================] - 0s 2ms/step - loss: 51568674.4640 - val_loss: 53064668.2581
#
# Epoch 00028: val_loss improved from 55488753.80645 to 53064668.25806, saving model to newModel/arrFans_health3_training_time_2_best_model_fold_3_config_8_8_8_4_ts100.h5
# Epoch 29/40
# 250/250 [==============================] - 0s 2ms/step - loss: 49184757.6640 - val_loss: 50611899.3548
#
# Epoch 00029: val_loss improved from 53064668.25806 to 50611899.35484, saving model to newModel/arrFans_health3_training_time_2_best_model_fold_3_config_8_8_8_4_ts100.h5
# Epoch 30/40
# 250/250 [==============================] - 0s 2ms/step - loss: 46795444.8960 - val_loss: 48130153.2903
#
# Epoch 00030: val_loss improved from 50611899.35484 to 48130153.29032, saving model to newModel/arrFans_health3_training_time_2_best_model_fold_3_config_8_8_8_4_ts100.h5
# Epoch 31/40
# 250/250 [==============================] - 0s 2ms/step - loss: 44359433.9840 - val_loss: 45652384.2581
#
# Epoch 00031: val_loss improved from 48130153.29032 to 45652384.25806, saving model to newModel/arrFans_health3_training_time_2_best_model_fold_3_config_8_8_8_4_ts100.h5
# Epoch 32/40
# 250/250 [==============================] - 0s 2ms/step - loss: 41939122.5920 - val_loss: 43174352.0000
#
# Epoch 00032: val_loss improved from 45652384.25806 to 43174352.00000, saving model to newModel/arrFans_health3_training_time_2_best_model_fold_3_config_8_8_8_4_ts100.h5
# Epoch 33/40
# 250/250 [==============================] - 0s 2ms/step - loss: 39523742.0800 - val_loss: 40703838.9677
#
# Epoch 00033: val_loss improved from 43174352.00000 to 40703838.96774, saving model to newModel/arrFans_health3_training_time_2_best_model_fold_3_config_8_8_8_4_ts100.h5
# Epoch 34/40
# 250/250 [==============================] - 0s 2ms/step - loss: 37137784.1920 - val_loss: 38245803.7419
#
# Epoch 00034: val_loss improved from 40703838.96774 to 38245803.74194, saving model to newModel/arrFans_health3_training_time_2_best_model_fold_3_config_8_8_8_4_ts100.h5
# Epoch 35/40
# 250/250 [==============================] - 0s 2ms/step - loss: 34761467.5200 - val_loss: 35823019.6129
#
# Epoch 00035: val_loss improved from 38245803.74194 to 35823019.61290, saving model to newModel/arrFans_health3_training_time_2_best_model_fold_3_config_8_8_8_4_ts100.h5
# Epoch 36/40
# 250/250 [==============================] - 0s 2ms/step - loss: 32428599.2000 - val_loss: 33441067.3548
#
# Epoch 00036: val_loss improved from 35823019.61290 to 33441067.35484, saving model to newModel/arrFans_health3_training_time_2_best_model_fold_3_config_8_8_8_4_ts100.h5
# Epoch 37/40
# 250/250 [==============================] - 0s 2ms/step - loss: 30115790.0640 - val_loss: 31129615.0323
#
# Epoch 00037: val_loss improved from 33441067.35484 to 31129615.03226, saving model to newModel/arrFans_health3_training_time_2_best_model_fold_3_config_8_8_8_4_ts100.h5
# Epoch 38/40
# 250/250 [==============================] - 0s 2ms/step - loss: 27893151.6160 - val_loss: 28870122.8387
#
# Epoch 00038: val_loss improved from 31129615.03226 to 28870122.83871, saving model to newModel/arrFans_health3_training_time_2_best_model_fold_3_config_8_8_8_4_ts100.h5
# Epoch 39/40
# 250/250 [==============================] - 0s 2ms/step - loss: 25745241.4880 - val_loss: 26666936.8387
#
# Epoch 00039: val_loss improved from 28870122.83871 to 26666936.83871, saving model to newModel/arrFans_health3_training_time_2_best_model_fold_3_config_8_8_8_4_ts100.h5
# Epoch 40/40
# 250/250 [==============================] - 0s 2ms/step - loss: 23641880.4160 - val_loss: 24551463.8065
#
# Epoch 00040: val_loss improved from 26666936.83871 to 24551463.80645, saving model to newModel/arrFans_health3_training_time_2_best_model_fold_3_config_8_8_8_4_ts100.h5
# 62/62 [==============================] - 5s 74ms/step
# Train on 250 samples, validate on 62 samples
# Epoch 1/40
# 250/250 [==============================] - 8s 31ms/step - loss: 85716715.1360 - val_loss: 81675619.6129
#
# Epoch 00001: val_loss improved from inf to 81675619.61290, saving model to newModel/arrFans_health3_training_time_2_best_model_fold_4_config_8_8_8_4_ts100.h5
# Epoch 2/40
# 250/250 [==============================] - 0s 2ms/step - loss: 85693610.7520 - val_loss: 81649166.9677
#
# Epoch 00002: val_loss improved from 81675619.61290 to 81649166.96774, saving model to newModel/arrFans_health3_training_time_2_best_model_fold_4_config_8_8_8_4_ts100.h5
# Epoch 3/40
# 250/250 [==============================] - 0s 2ms/step - loss: 85657603.9040 - val_loss: 81604570.0645
#
# Epoch 00003: val_loss improved from 81649166.96774 to 81604570.06452, saving model to newModel/arrFans_health3_training_time_2_best_model_fold_4_config_8_8_8_4_ts100.h5
# Epoch 4/40
# 250/250 [==============================] - 0s 2ms/step - loss: 85599922.8800 - val_loss: 81534153.5484
#
# Epoch 00004: val_loss improved from 81604570.06452 to 81534153.54839, saving model to newModel/arrFans_health3_training_time_2_best_model_fold_4_config_8_8_8_4_ts100.h5
# Epoch 5/40
# 250/250 [==============================] - 0s 2ms/step - loss: 85514580.3520 - val_loss: 81437208.0000
#
# Epoch 00005: val_loss improved from 81534153.54839 to 81437208.00000, saving model to newModel/arrFans_health3_training_time_2_best_model_fold_4_config_8_8_8_4_ts100.h5
# Epoch 6/40
# 250/250 [==============================] - 0s 2ms/step - loss: 85409466.6240 - val_loss: 81315912.7742
#
# Epoch 00006: val_loss improved from 81437208.00000 to 81315912.77419, saving model to newModel/arrFans_health3_training_time_2_best_model_fold_4_config_8_8_8_4_ts100.h5
# Epoch 7/40
# 250/250 [==============================] - 0s 2ms/step - loss: 85278860.9920 - val_loss: 81168379.0968
#
# Epoch 00007: val_loss improved from 81315912.77419 to 81168379.09677, saving model to newModel/arrFans_health3_training_time_2_best_model_fold_4_config_8_8_8_4_ts100.h5
# Epoch 8/40
# 250/250 [==============================] - 1s 2ms/step - loss: 85124949.9520 - val_loss: 80990341.9355
#
# Epoch 00008: val_loss improved from 81168379.09677 to 80990341.93548, saving model to newModel/arrFans_health3_training_time_2_best_model_fold_4_config_8_8_8_4_ts100.h5
# Epoch 9/40
# 250/250 [==============================] - 0s 2ms/step - loss: 84944800.7680 - val_loss: 80781897.2903
#
# Epoch 00009: val_loss improved from 80990341.93548 to 80781897.29032, saving model to newModel/arrFans_health3_training_time_2_best_model_fold_4_config_8_8_8_4_ts100.h5
# Epoch 10/40
# 250/250 [==============================] - 0s 2ms/step - loss: 84724156.7360 - val_loss: 80549270.9677
#
# Epoch 00010: val_loss improved from 80781897.29032 to 80549270.96774, saving model to newModel/arrFans_health3_training_time_2_best_model_fold_4_config_8_8_8_4_ts100.h5
# Epoch 11/40
# 250/250 [==============================] - 0s 2ms/step - loss: 84486971.7760 - val_loss: 80280349.1613
#
# Epoch 00011: val_loss improved from 80549270.96774 to 80280349.16129, saving model to newModel/arrFans_health3_training_time_2_best_model_fold_4_config_8_8_8_4_ts100.h5
# Epoch 12/40
# 250/250 [==============================] - 0s 2ms/step - loss: 84198178.0480 - val_loss: 79978353.8065
#
# Epoch 00012: val_loss improved from 80280349.16129 to 79978353.80645, saving model to newModel/arrFans_health3_training_time_2_best_model_fold_4_config_8_8_8_4_ts100.h5
# Epoch 13/40
# 250/250 [==============================] - 0s 2ms/step - loss: 83868810.9440 - val_loss: 79618939.8710
#
# Epoch 00013: val_loss improved from 79978353.80645 to 79618939.87097, saving model to newModel/arrFans_health3_training_time_2_best_model_fold_4_config_8_8_8_4_ts100.h5
# Epoch 14/40
# 250/250 [==============================] - 0s 2ms/step - loss: 83499674.4320 - val_loss: 79218871.2258
#
# Epoch 00014: val_loss improved from 79618939.87097 to 79218871.22581, saving model to newModel/arrFans_health3_training_time_2_best_model_fold_4_config_8_8_8_4_ts100.h5
# Epoch 15/40
# 250/250 [==============================] - 0s 2ms/step - loss: 83034051.6480 - val_loss: 78699882.3226
#
# Epoch 00015: val_loss improved from 79218871.22581 to 78699882.32258, saving model to newModel/arrFans_health3_training_time_2_best_model_fold_4_config_8_8_8_4_ts100.h5
# Epoch 16/40
# 250/250 [==============================] - 0s 2ms/step - loss: 82490622.8480 - val_loss: 77982025.2903
#
# Epoch 00016: val_loss improved from 78699882.32258 to 77982025.29032, saving model to newModel/arrFans_health3_training_time_2_best_model_fold_4_config_8_8_8_4_ts100.h5
# Epoch 17/40
# 250/250 [==============================] - 1s 2ms/step - loss: 81922949.4400 - val_loss: 77292299.0968
#
# Epoch 00017: val_loss improved from 77982025.29032 to 77292299.09677, saving model to newModel/arrFans_health3_training_time_2_best_model_fold_4_config_8_8_8_4_ts100.h5
# Epoch 18/40
# 250/250 [==============================] - 0s 2ms/step - loss: 81358137.6640 - val_loss: 76674395.8710
#
# Epoch 00018: val_loss improved from 77292299.09677 to 76674395.87097, saving model to newModel/arrFans_health3_training_time_2_best_model_fold_4_config_8_8_8_4_ts100.h5
# Epoch 19/40
# 250/250 [==============================] - 0s 2ms/step - loss: 80780380.6080 - val_loss: 76040451.8710
#
# Epoch 00019: val_loss improved from 76674395.87097 to 76040451.87097, saving model to newModel/arrFans_health3_training_time_2_best_model_fold_4_config_8_8_8_4_ts100.h5
# Epoch 20/40
# 250/250 [==============================] - 0s 2ms/step - loss: 80157231.1040 - val_loss: 75363717.4194
#
# Epoch 00020: val_loss improved from 76040451.87097 to 75363717.41935, saving model to newModel/arrFans_health3_training_time_2_best_model_fold_4_config_8_8_8_4_ts100.h5
# Epoch 21/40
# 250/250 [==============================] - 1s 2ms/step - loss: 79519800.0000 - val_loss: 74539288.7742
#
# Epoch 00021: val_loss improved from 75363717.41935 to 74539288.77419, saving model to newModel/arrFans_health3_training_time_2_best_model_fold_4_config_8_8_8_4_ts100.h5
# Epoch 22/40
# 250/250 [==============================] - 0s 2ms/step - loss: 78843175.6160 - val_loss: 73784479.7419
#
# Epoch 00022: val_loss improved from 74539288.77419 to 73784479.74194, saving model to newModel/arrFans_health3_training_time_2_best_model_fold_4_config_8_8_8_4_ts100.h5
# Epoch 23/40
# 250/250 [==============================] - 1s 2ms/step - loss: 78142695.1680 - val_loss: 73004352.5161
#
# Epoch 00023: val_loss improved from 73784479.74194 to 73004352.51613, saving model to newModel/arrFans_health3_training_time_2_best_model_fold_4_config_8_8_8_4_ts100.h5
# Epoch 24/40
# 250/250 [==============================] - 1s 2ms/step - loss: 77426112.8320 - val_loss: 72186436.9032
#
# Epoch 00024: val_loss improved from 73004352.51613 to 72186436.90323, saving model to newModel/arrFans_health3_training_time_2_best_model_fold_4_config_8_8_8_4_ts100.h5
# Epoch 25/40
# 250/250 [==============================] - 0s 2ms/step - loss: 76664545.6640 - val_loss: 71343507.8710
#
# Epoch 00025: val_loss improved from 72186436.90323 to 71343507.87097, saving model to newModel/arrFans_health3_training_time_2_best_model_fold_4_config_8_8_8_4_ts100.h5
# Epoch 26/40
# 250/250 [==============================] - 1s 2ms/step - loss: 75879941.8880 - val_loss: 70477843.0968
#
# Epoch 00026: val_loss improved from 71343507.87097 to 70477843.09677, saving model to newModel/arrFans_health3_training_time_2_best_model_fold_4_config_8_8_8_4_ts100.h5
# Epoch 27/40
# 250/250 [==============================] - 0s 2ms/step - loss: 75118120.5760 - val_loss: 69587931.0968
#
# Epoch 00027: val_loss improved from 70477843.09677 to 69587931.09677, saving model to newModel/arrFans_health3_training_time_2_best_model_fold_4_config_8_8_8_4_ts100.h5
# Epoch 28/40
# 250/250 [==============================] - 0s 2ms/step - loss: 74268712.7680 - val_loss: 68916116.1290
#
# Epoch 00028: val_loss improved from 69587931.09677 to 68916116.12903, saving model to newModel/arrFans_health3_training_time_2_best_model_fold_4_config_8_8_8_4_ts100.h5
# Epoch 29/40
# 250/250 [==============================] - 0s 2ms/step - loss: 73409233.1520 - val_loss: 67970323.8710
#
# Epoch 00029: val_loss improved from 68916116.12903 to 67970323.87097, saving model to newModel/arrFans_health3_training_time_2_best_model_fold_4_config_8_8_8_4_ts100.h5
# Epoch 30/40
# 250/250 [==============================] - 0s 2ms/step - loss: 72484149.9520 - val_loss: 67016970.8387
#
# Epoch 00030: val_loss improved from 67970323.87097 to 67016970.83871, saving model to newModel/arrFans_health3_training_time_2_best_model_fold_4_config_8_8_8_4_ts100.h5
# Epoch 31/40
# 250/250 [==============================] - 0s 2ms/step - loss: 71538742.1440 - val_loss: 66031820.0000
#
# Epoch 00031: val_loss improved from 67016970.83871 to 66031820.00000, saving model to newModel/arrFans_health3_training_time_2_best_model_fold_4_config_8_8_8_4_ts100.h5
# Epoch 32/40
# 250/250 [==============================] - 1s 2ms/step - loss: 70547937.6640 - val_loss: 65026363.4839
#
# Epoch 00032: val_loss improved from 66031820.00000 to 65026363.48387, saving model to newModel/arrFans_health3_training_time_2_best_model_fold_4_config_8_8_8_4_ts100.h5
# Epoch 33/40
# 250/250 [==============================] - 0s 2ms/step - loss: 69538654.5280 - val_loss: 63973045.6774
#
# Epoch 00033: val_loss improved from 65026363.48387 to 63973045.67742, saving model to newModel/arrFans_health3_training_time_2_best_model_fold_4_config_8_8_8_4_ts100.h5
# Epoch 34/40
# 250/250 [==============================] - 0s 2ms/step - loss: 68469837.8880 - val_loss: 62891864.7742
#
# Epoch 00034: val_loss improved from 63973045.67742 to 62891864.77419, saving model to newModel/arrFans_health3_training_time_2_best_model_fold_4_config_8_8_8_4_ts100.h5
# Epoch 35/40
# 250/250 [==============================] - 0s 2ms/step - loss: 67369960.8320 - val_loss: 61771981.4194
#
# Epoch 00035: val_loss improved from 62891864.77419 to 61771981.41935, saving model to newModel/arrFans_health3_training_time_2_best_model_fold_4_config_8_8_8_4_ts100.h5
# Epoch 36/40
# 250/250 [==============================] - 0s 2ms/step - loss: 66217427.8400 - val_loss: 60624358.3226
#
# Epoch 00036: val_loss improved from 61771981.41935 to 60624358.32258, saving model to newModel/arrFans_health3_training_time_2_best_model_fold_4_config_8_8_8_4_ts100.h5
# Epoch 37/40
# 250/250 [==============================] - 0s 2ms/step - loss: 65007257.4080 - val_loss: 59116334.1935
#
# Epoch 00037: val_loss improved from 60624358.32258 to 59116334.19355, saving model to newModel/arrFans_health3_training_time_2_best_model_fold_4_config_8_8_8_4_ts100.h5
# Epoch 38/40
# 250/250 [==============================] - 0s 2ms/step - loss: 63746057.7920 - val_loss: 57873498.3226
#
# Epoch 00038: val_loss improved from 59116334.19355 to 57873498.32258, saving model to newModel/arrFans_health3_training_time_2_best_model_fold_4_config_8_8_8_4_ts100.h5
# Epoch 39/40
# 250/250 [==============================] - 0s 2ms/step - loss: 62409465.8880 - val_loss: 56568966.3226
#
# Epoch 00039: val_loss improved from 57873498.32258 to 56568966.32258, saving model to newModel/arrFans_health3_training_time_2_best_model_fold_4_config_8_8_8_4_ts100.h5
# Epoch 40/40
# 250/250 [==============================] - 0s 2ms/step - loss: 61000175.0080 - val_loss: 55227387.2258
#
# Epoch 00040: val_loss improved from 56568966.32258 to 55227387.22581, saving model to newModel/arrFans_health3_training_time_2_best_model_fold_4_config_8_8_8_4_ts100.h5
# 62/62 [==============================] - 5s 77ms/step

# %%
print ('start time: ',  datetime.timestamp(start_time))
print ('end time:', datetime.timestamp(end_time))
print ('training time: ', datetime.timestamp(end_time)-datetime.timestamp(start_time))
# Out:
# start time:  1572797415.491869
# end time: 1572800001.089023
# training time:  2585.5971541404724

# %%
msescores
# Out:
# [{'path': 'newModel/arrFans_health3_training_time_0_best_model_fold_0_config_8_8_8_4_ts100.h5',
#   'mse': 21971569.936507937},
#  {'path': 'newModel/arrFans_health3_training_time_0_best_model_fold_1_config_8_8_8_4_ts100.h5',
#   'mse': 61012857.71428572},
#  {'path': 'newModel/arrFans_health3_training_time_0_best_model_fold_2_config_8_8_8_4_ts100.h5',
#   'mse': 9258161.096774194},
#  {'path': 'newModel/arrFans_health3_training_time_0_best_model_fold_3_config_8_8_8_4_ts100.h5',
#   'mse': 39854844.0},
#  {'path': 'newModel/arrFans_health3_training_time_0_best_model_fold_4_config_8_8_8_4_ts100.h5',
#   'mse': 46101910.96774194},
#  {'path': 'newModel/arrFans_health3_training_time_1_best_model_fold_0_config_8_8_8_4_ts100.h5',
#   'mse': 44180529.07936508},
#  {'path': 'newModel/arrFans_health3_training_time_1_best_model_fold_1_config_8_8_8_4_ts100.h5',
#   'mse': 24641518.85714286},
#  {'path': 'newModel/arrFans_health3_training_time_1_best_model_fold_2_config_8_8_8_4_ts100.h5',
#   'mse': 51803455.87096774},
#  {'path': 'newModel/arrFans_health3_training_time_1_best_model_fold_3_config_8_8_8_4_ts100.h5',
#   'mse': 39482209.80645161},
#  {'path': 'newModel/arrFans_health3_training_time_1_best_model_fold_4_config_8_8_8_4_ts100.h5',
#   'mse': 25086781.80645161},
#  {'path': 'newModel/arrFans_health3_training_time_2_best_model_fold_0_config_8_8_8_4_ts100.h5',
#   'mse': 74580891.68253969},
#  {'path': 'newModel/arrFans_health3_training_time_2_best_model_fold_1_config_8_8_8_4_ts100.h5',
#   'mse': 51839307.746031746},
#  {'path': 'newModel/arrFans_health3_training_time_2_best_model_fold_2_config_8_8_8_4_ts100.h5',
#   'mse': 62896327.741935484},
#  {'path': 'newModel/arrFans_health3_training_time_2_best_model_fold_3_config_8_8_8_4_ts100.h5',
#   'mse': 24551463.80645161},
#  {'path': 'newModel/arrFans_health3_training_time_2_best_model_fold_4_config_8_8_8_4_ts100.h5',
#   'mse': 55227387.22580645}]

# %%
timeList
# Out:
# [{'start': datetime.datetime(2019, 11, 3, 9, 46, 51, 767594),
#   'end': datetime.datetime(2019, 11, 3, 9, 51, 59, 546358),
#   'time': 307.7787640094757},
#  {'start': datetime.datetime(2019, 11, 3, 9, 51, 59, 546365),
#   'end': datetime.datetime(2019, 11, 3, 10, 10, 15, 491861),
#   'time': 1095.945496082306},
#  {'start': datetime.datetime(2019, 11, 3, 10, 10, 15, 491869),
#   'end': datetime.datetime(2019, 11, 3, 10, 53, 21, 89023),
#   'time': 2585.5971541404724}]

# %%
# Plot and see data distribution

from matplotlib import pyplot as plt
import seaborn as sns

def plotAttrDataOfId(data, compute, features):
    plt.figure(figsize=(30, 20))
    for i, v in enumerate(features):
        plt.subplot(10, 3, i+1)
        cDf = df[df['compute']==compute]
        plt.plot(cDf['timespan'], cDf[v])
        plt.title(v)
        plt.tight_layout()

# %%
# for x in np.random.randint(0, len(computes), 3):
#     plotAttrDataOfId(df, computes[x], features)

# %%
def plotDataDistribution(data, features):
    plt.figure(figsize=(30, 10))
    for i, v in enumerate(features):
        plt.subplot(3, 10, i+1)
        sns.distplot(list(data[v].values))
        plt.title(v)
    plt.tight_layout()

# %%
# plotDataDistribution(df, features)

# %%
from datetime import datetime
print(datetime.now().strftime("%H_%M_%S"))

# %%
[i for i in range(1,11
                 )]

# %%
sns.distplot(y_train)

# %%
sns.distplot(y_test)

# %%
print (type(X_dfs[0]))
