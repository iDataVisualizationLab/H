# %%
import graphlab

# %%
import plotly

# %%
import plotly.plotly as py
plotly.tools.set_credentials_file(username='phamvanvung', api_key='ta8O2vcNibZrNEdNdMKk')
import plotly.graph_objs as go

# %%
soils = graphlab.SFrame('../data/Profile1.csv')
# Out:
# This non-commercial license of GraphLab Create for academic use is assigned to vungpv@fpt.edu.vn and will expire on May 03, 2019.
# [INFO] graphlab.cython.cy_server: GraphLab Create v2.1 started. Logging: /tmp/graphlab_server_1527954656.log
# Finished parsing file /Users/idvlab/Documents/TTU/htdocs/Soil/data/Profile1.csv
# Parsing completed. Parsed 100 lines in 0.050051 secs.
# ------------------------------------------------------
# Inferred types from first 100 line(s) of file as
# ...

# %%
soils
# Out:
# Columns:
# 	Reading #	int
# 	Method Name	str
# 	User Factor Name	str
# 	Test Label	int
# 	Grid ID	str
# 	Latitude	float
# 	Longitude	float
# 	Elevation	float
# 	Pseudo Element Config Name	str
# 	Date	str
# 	Time	str
# 	Units	str
# 	Mg Compound Level	str
# 	Mg Compound Error	str
# 	Mg Concentration	str
# 	Mg Error 1s	int
# 	Al Compound	str
# 	Al Compound Level	str
# 	Al Compound Error	str
# 	Al Concentration	int
# 	Al Error 1s	int
# 	Si Compound	str
# 	Si Compound Level	str
# 	Si Compound Error	str
# 	Si Concentration	int
# 	Si Error 1s	int
# 	P Compound	str
# 	P Compound Level	str
# 	P Compound Error	str
# 	P Concentration	str
# 	P Error 1s	int
# 	S Compound	str
# 	S Compound Level	str
# 	S Compound Error	str
# 	S Concentration	str
# 	S Error 1s	int
# 	K Compound	str
# 	K Compound Level	str
# 	K Compound Error	str
# 	K Concentration	int
# 	K Error 1s	int
# 	Ca Compound	str
# 	Ca Compound Level	str
# 	Ca Compound Error	str
# 	Ca Concentration	int
# 	Ca Error 1s	int
# 	Ti Compound	str
# ...

# %%
#Filter data
def validGridId(id):
    import re
    pattern = '^[A-Z]\d\d$'
    return re.match(pattern, id)!= None
filterLst = soils['Grid ID'].apply(validGridId)
soils = soils[filterLst]

# %%
soils.num_rows()
# Out:
# 130

# %%
def splitGridId(gridId):
    gridLetter = gridId[0:1]
    gridNumber = gridId[1:]
    return (gridLetter, gridNumber)
def extractGridLetter(gridId):
    (gridLetter, gridNumber) = splitGridId(gridId)
    return gridLetter
def extractGridNumber(gridId):
    (gridLetter, gridNumber) = splitGridId(gridId)
    return gridNumber

# %%
x = list(soils['Grid ID'].apply(extractGridNumber))
y = list(soils['Grid ID'].apply(extractGridLetter))
zAl = list(soils['Al Concentration'])
zMg = list(soils['Mg Concentration'])
zSi = list(soils['Si Concentration'])

# %%
dataAl = [go.Contour(x = x, y = y, z = zAl)]

# %%
py.iplot(data)
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~phamvanvung/88.embed" height="525px" width="100%"></iframe>

# %%
x = list(soils['Grid ID'])
yAl = list(soils['Al Concentration'])
yMg = list(soils['Mg Concentration'])
ySi = list(soils['Si Concentration'])

# %%
data = [go.Scatter(x=x, y=yAl, name='Al'), go.Scatter(x=x, y=yMg, name='Mg'), go.Scatter(x=x, y=ySi, name='Si')]

# %%
py.iplot(data)
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~phamvanvung/92.embed" height="525px" width="100%"></iframe>
