# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os

# %%
import json
with open("service1906_1506.json") as of:
    data = json.load(of)

# %%
computes = [c for c in data.keys() if c!="timespan"]
variables = [v for v in data[computes[0]] if v!='index' and v!='arrJob_scheduling']

# %%
#Check empty array
def getEmptyArr(data, c):
    cObj = data[c]
    cDf = pd.DataFrame()
    cDf['compute'] = [c for _ in data['timespan']]
    cDf['timespan'] = data['timespan']
    for v in variables:
        vArr = np.array(cObj[v])
        if len(vArr)==0:
            print('c=', c)
            print('v=', v)
for c in computes:
    getEmptyArr(data, c)

# %%
def addTarget(cDf, predictedVar, predictedStep, target):
    cDf[target] = cDf[predictedVar].shift(-predictedStep)
    cDf.dropna(inplace=True)
    return cDf

# %%
def getComputeDf(data, c, predictedVar, predictedStep, target):
    cObj = data[c]
    cDf = pd.DataFrame()
    cDf['compute'] = [c for _ in data['timespan']]
    cDf['timespan'] = data['timespan']
    for v in variables:
        vArr = np.array(cObj[v])
        if len(vArr)==0:
            return None
        else:
            for i in range(len(vArr[0])):
                cDf[v+str(i)] = vArr[:, i]
    cDf['timespan'] = pd.to_datetime(cDf['timespan'])
    return addTarget(cDf, predictedVar, predictedStep, target)

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from IPython.display import FileLink
import codecs, json

# %%
def exportNPArrayToJson(a, fileName):
    b = a.tolist()
    json.dump(b, codecs.open(fileName, 'w', encoding='utf-8'))

# %%
def splitTrainTest(predictedVar):
    target = predictedVar + "_target"
    predictedSteps = 4
    df = pd.concat([x for x in [getComputeDf(data, c, predictedVar, predictedSteps, target) for c in computes] if type(x)!="NoneType"])
    
    df = df.reset_index().drop('index', axis=1)
    features = [x for x in df.columns if x not in ['compute', 'timespan', target]]
        
    X_dfs = []
    y = []
    numberOfSequences = 1
    # generate training data.
    for compute in computes:
        cDf = df[df['compute']==compute]
        if(len(cDf) > sequenceSteps):
            randSteps = np.random.randint(0, len(cDf)-sequenceSteps, numberOfSequences)
            for randStep in randSteps:
                X_dfs.append(cDf.iloc[randStep:randStep+sequenceSteps])
                y.append(X_dfs[-1][target].values[-1])

    X_train_dfs, X_test_dfs, y_train, y_test = train_test_split(X_dfs, y, test_size=0.33)
            
    #Scale data

    # combine the training data to create a scaler
    train_dfs = pd.concat(X_train_dfs)

    scaler = StandardScaler().fit(train_dfs[features].values)
    
    X_train = np.array([scaler.transform(item[features].values) for item in X_train_dfs])
    X_test = np.array([scaler.transform(item[features].values) for item in X_test_dfs])
    y_train = np.array(y_train)
    y_test = np.array(y_test)
    
    exportNPArrayToJson(X_train, 'newData/'+target+'_X_train_HPCC_'+str(sequenceSteps)+'.json')
    exportNPArrayToJson(X_test, 'newData/'+target+'_X_test_HPCC_'+str(sequenceSteps)+'.json')
    exportNPArrayToJson(y_train, 'newData/'+target+'_y_train_HPCC_'+str(sequenceSteps)+'.json')
    exportNPArrayToJson(y_test, 'newData/'+target+'_y_test_HPCC_'+str(sequenceSteps)+'.json')
    
    FileLink('newData/'+target+'_X_train_HPCC_'+str(sequenceSteps)+'.json')
    FileLink('newData/'+target+'_X_test_HPCC_'+str(sequenceSteps)+'.json')
    FileLink('newData/'+target+'_y_train_HPCC_'+str(sequenceSteps)+'.json')
    FileLink('newData/'+target+'_y_test_HPCC_'+str(sequenceSteps)+'.json')
    
    return (X_train, X_test, y_train, y_test)

# %%
from keras import regularizers
from keras.models import Sequential
from keras.layers import LSTM
from keras.layers import Dense
from keras.layers import Activation
from keras.layers import Dropout
from keras.layers import Flatten
import tensorflow as tf

SEED = 1711
import os
import random as rn
import numpy as np
from tensorflow import set_random_seed

os.environ['PYTHONHASHSEED']=str(SEED)
np.random.seed(SEED)
set_random_seed(SEED)
rn.seed(SEED)

from keras import backend as K
session_conf = tf.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
sess = tf.Session(graph=tf.get_default_graph(), config=session_conf)
K.set_session(sess)
# from keras import backend as K
# K.set_session(K.tf.Session(config=K.tf.ConfigProto(intra_op_parallelism_threads=36, inter_op_parallelism_threads=36)))


def createModel(l1Nodes, l2Nodes, d1Nodes, d2Nodes, inputShape):
    # input layer
    lstm1 = LSTM(l1Nodes, input_shape=inputShape, return_sequences=True, kernel_regularizer=regularizers.l2(0.1))
    do1 = Dropout(0.2)
    
    lstm2 = LSTM(l2Nodes, return_sequences=True, kernel_regularizer=regularizers.l2(0.1))
    do2 = Dropout(0.2)
    
    flatten = Flatten()
    
    dense1 = Dense(d1Nodes, activation='relu')
    do3 = Dropout(0.2)
    
    dense2 = Dense(d2Nodes, activation='relu')
    do4 = Dropout(0.2)
    
    # output layer
    outL = Dense(1, activation='relu')
    # combine the layers
#     layers = [lstm1, do1, lstm2, do2, dense1, do3, dense2, do4, outL]
#     layers = [lstm1, lstm2, flatten,  dense1, dense2, outL]
#     layers = [lstm1, flatten,  dense1, outL]
    layers = [lstm1, lstm2, flatten,  dense1, outL]

    # create the model
    model = Sequential(layers)
    model.compile(optimizer='adam', loss='mse')
    return model
# Out:
# Using TensorFlow backend.

# %%
from keras.callbacks import ModelCheckpoint
from keras.callbacks import EarlyStopping
from keras.models import load_model
# ten fold
from sklearn.model_selection import KFold
kfold = KFold(n_splits=5, shuffle=True)
from datetime import datetime

sequenceSteps = 100

msescores = []
model_config = "config_8_4_2_ts"+str(sequenceSteps)

tempAllVariables = ['arrTemperature0', 'arrTemperature1', 'arrTemperature2', 'arrCPU_load0', 'arrMemory_usage0', 'arrFans_health0', 'arrFans_health1', 'arrFans_health2', 'arrFans_health3', 'arrPower_usage0']
allVariables = ['arrTemperature0']
timeList = []



for feature in allVariables:
    print(feature)
    X_train, X_test, y_train, Y_test = splitTrainTest(feature)

    for training_time in range(0,3):
        start_time = datetime.now()
        print(start_time)

        counter= 0
        for trainIdx, testIdx in kfold.split(X_train, y_train):
            # create callbacks
            model_path = feature+'_training_time_'+str(training_time)+'_best_model_fold_'+str(counter)+"_"+model_config+'.h5'
            mc = ModelCheckpoint('newModel/'+model_path, monitor='val_loss', mode='min', verbose=1, save_best_only=True)
            es = EarlyStopping(monitor='val_loss', min_delta=0, patience=3, verbose=1)
            # create model
            model = createModel(l1Nodes = 8, l2Nodes = 4, d1Nodes = 2, d2Nodes = 0, inputShape= (X_train.shape[1], X_train.shape[2]))
            model.fit(X_train[trainIdx], y_train[trainIdx], validation_data=(X_train[testIdx], y_train[testIdx]), batch_size=32, epochs=40, callbacks=[mc, es])
            # Done load the best model of this fold
            saved_model = load_model('newModel/' + model_path)
            msescores.append({'path': 'newModel/' + model_path, 'mse': saved_model.evaluate(X_train[testIdx], y_train[testIdx])})
            counter = counter + 1
        
#             tfjs.converters.save_keras_model(saved_model, 'newModel/'+model_path)

        end_time = datetime.now()
    
        timeList.append({'start': start_time, 'end': end_time, 'time': datetime.timestamp(end_time)-datetime.timestamp(start_time)})
# Out:
# arrTemperature0
# 2019-11-06 16:35:53.888283
# WARNING:tensorflow:From /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Train on 249 samples, validate on 63 samples
# Epoch 1/40
# 249/249 [==============================] - 1s 4ms/step - loss: 3528.6710 - val_loss: 3231.7858
#
# Epoch 00001: val_loss improved from inf to 3231.78578, saving model to newModel/arrTemperature0_training_time_0_best_model_fold_0_config_8_4_2_ts100.h5
# Epoch 2/40
# 249/249 [==============================] - 0s 1ms/step - loss: 3489.2711 - val_loss: 3197.9743
#
# Epoch 00002: val_loss improved from 3231.78578 to 3197.97429, saving model to newModel/arrTemperature0_training_time_0_best_model_fold_0_config_8_4_2_ts100.h5
# Epoch 3/40
# 249/249 [==============================] - 0s 1ms/step - loss: 3440.8999 - val_loss: 3146.7459
#
# Epoch 00003: val_loss improved from 3197.97429 to 3146.74588, saving model to newModel/arrTemperature0_training_time_0_best_model_fold_0_config_8_4_2_ts100.h5
# Epoch 4/40
# 249/249 [==============================] - 0s 1ms/step - loss: 3373.0953 - val_loss: 3078.3618
#
# Epoch 00004: val_loss improved from 3146.74588 to 3078.36176, saving model to newModel/arrTemperature0_training_time_0_best_model_fold_0_config_8_4_2_ts100.h5
# Epoch 5/40
# 249/249 [==============================] - 0s 1ms/step - loss: 3283.8468 - val_loss: 2984.0224
#
# Epoch 00005: val_loss improved from 3078.36176 to 2984.02245, saving model to newModel/arrTemperature0_training_time_0_best_model_fold_0_config_8_4_2_ts100.h5
# Epoch 6/40
# 249/249 [==============================] - 0s 1ms/step - loss: 3168.3292 - val_loss: 2839.3696
#
# Epoch 00006: val_loss improved from 2984.02245 to 2839.36956, saving model to newModel/arrTemperature0_training_time_0_best_model_fold_0_config_8_4_2_ts100.h5
# Epoch 7/40
# 249/249 [==============================] - 0s 1ms/step - loss: 3007.4140 - val_loss: 2663.6026
#
# Epoch 00007: val_loss improved from 2839.36956 to 2663.60257, saving model to newModel/arrTemperature0_training_time_0_best_model_fold_0_config_8_4_2_ts100.h5
# Epoch 8/40
# 249/249 [==============================] - 0s 1ms/step - loss: 2811.1808 - val_loss: 2451.2398
#
# Epoch 00008: val_loss improved from 2663.60257 to 2451.23984, saving model to newModel/arrTemperature0_training_time_0_best_model_fold_0_config_8_4_2_ts100.h5
# Epoch 9/40
# 249/249 [==============================] - 0s 1ms/step - loss: 2571.4755 - val_loss: 2218.9694
#
# Epoch 00009: val_loss improved from 2451.23984 to 2218.96944, saving model to newModel/arrTemperature0_training_time_0_best_model_fold_0_config_8_4_2_ts100.h5
# Epoch 10/40
# 249/249 [==============================] - 0s 1ms/step - loss: 2314.0058 - val_loss: 1974.3384
#
# Epoch 00010: val_loss improved from 2218.96944 to 1974.33842, saving model to newModel/arrTemperature0_training_time_0_best_model_fold_0_config_8_4_2_ts100.h5
# Epoch 11/40
# 249/249 [==============================] - 0s 1ms/step - loss: 2049.7384 - val_loss: 1729.7965
#
# Epoch 00011: val_loss improved from 1974.33842 to 1729.79653, saving model to newModel/arrTemperature0_training_time_0_best_model_fold_0_config_8_4_2_ts100.h5
# Epoch 12/40
# 249/249 [==============================] - 0s 1ms/step - loss: 1787.6782 - val_loss: 1489.9387
#
# Epoch 00012: val_loss improved from 1729.79653 to 1489.93869, saving model to newModel/arrTemperature0_training_time_0_best_model_fold_0_config_8_4_2_ts100.h5
# Epoch 13/40
# 249/249 [==============================] - 0s 1ms/step - loss: 1533.5965 - val_loss: 1261.3016
#
# Epoch 00013: val_loss improved from 1489.93869 to 1261.30159, saving model to newModel/arrTemperature0_training_time_0_best_model_fold_0_config_8_4_2_ts100.h5
# Epoch 14/40
# 249/249 [==============================] - 0s 1ms/step - loss: 1292.9252 - val_loss: 1049.3792
#
# Epoch 00014: val_loss improved from 1261.30159 to 1049.37924, saving model to newModel/arrTemperature0_training_time_0_best_model_fold_0_config_8_4_2_ts100.h5
# Epoch 15/40
# 249/249 [==============================] - 0s 1ms/step - loss: 1072.0347 - val_loss: 856.4730
#
# Epoch 00015: val_loss improved from 1049.37924 to 856.47303, saving model to newModel/arrTemperature0_training_time_0_best_model_fold_0_config_8_4_2_ts100.h5
# Epoch 16/40
# 249/249 [==============================] - 0s 1ms/step - loss: 871.4969 - val_loss: 690.0176
#
# Epoch 00016: val_loss improved from 856.47303 to 690.01757, saving model to newModel/arrTemperature0_training_time_0_best_model_fold_0_config_8_4_2_ts100.h5
# Epoch 17/40
# 249/249 [==============================] - 0s 1ms/step - loss: 702.2244 - val_loss: 552.2624
#
# Epoch 00017: val_loss improved from 690.01757 to 552.26239, saving model to newModel/arrTemperature0_training_time_0_best_model_fold_0_config_8_4_2_ts100.h5
# Epoch 18/40
# 249/249 [==============================] - 0s 1ms/step - loss: 563.4005 - val_loss: 442.1853
#
# Epoch 00018: val_loss improved from 552.26239 to 442.18534, saving model to newModel/arrTemperature0_training_time_0_best_model_fold_0_config_8_4_2_ts100.h5
# Epoch 19/40
# 249/249 [==============================] - 0s 1ms/step - loss: 449.0207 - val_loss: 359.5972
#
# Epoch 00019: val_loss improved from 442.18534 to 359.59720, saving model to newModel/arrTemperature0_training_time_0_best_model_fold_0_config_8_4_2_ts100.h5
# Epoch 20/40
# 249/249 [==============================] - 0s 1ms/step - loss: 366.5713 - val_loss: 298.3402
#
# Epoch 00020: val_loss improved from 359.59720 to 298.34024, saving model to newModel/arrTemperature0_training_time_0_best_model_fold_0_config_8_4_2_ts100.h5
# Epoch 21/40
# 249/249 [==============================] - 0s 1ms/step - loss: 303.9805 - val_loss: 255.5153
#
# Epoch 00021: val_loss improved from 298.34024 to 255.51531, saving model to newModel/arrTemperature0_training_time_0_best_model_fold_0_config_8_4_2_ts100.h5
# Epoch 22/40
# 249/249 [==============================] - 0s 1ms/step - loss: 261.1500 - val_loss: 225.4520
#
# Epoch 00022: val_loss improved from 255.51531 to 225.45198, saving model to newModel/arrTemperature0_training_time_0_best_model_fold_0_config_8_4_2_ts100.h5
# Epoch 23/40
# 249/249 [==============================] - 0s 1ms/step - loss: 229.3189 - val_loss: 204.3440
#
# Epoch 00023: val_loss improved from 225.45198 to 204.34396, saving model to newModel/arrTemperature0_training_time_0_best_model_fold_0_config_8_4_2_ts100.h5
# Epoch 24/40
# 249/249 [==============================] - 0s 1ms/step - loss: 207.1392 - val_loss: 187.8293
#
# Epoch 00024: val_loss improved from 204.34396 to 187.82926, saving model to newModel/arrTemperature0_training_time_0_best_model_fold_0_config_8_4_2_ts100.h5
# Epoch 25/40
# 249/249 [==============================] - 0s 1ms/step - loss: 190.3770 - val_loss: 172.9802
#
# Epoch 00025: val_loss improved from 187.82926 to 172.98023, saving model to newModel/arrTemperature0_training_time_0_best_model_fold_0_config_8_4_2_ts100.h5
# Epoch 26/40
# 249/249 [==============================] - 0s 1ms/step - loss: 176.7918 - val_loss: 163.4911
#
# Epoch 00026: val_loss improved from 172.98023 to 163.49110, saving model to newModel/arrTemperature0_training_time_0_best_model_fold_0_config_8_4_2_ts100.h5
# Epoch 27/40
# 249/249 [==============================] - 0s 1ms/step - loss: 165.4447 - val_loss: 156.5039
#
# Epoch 00027: val_loss improved from 163.49110 to 156.50386, saving model to newModel/arrTemperature0_training_time_0_best_model_fold_0_config_8_4_2_ts100.h5
# Epoch 28/40
# 249/249 [==============================] - 0s 1ms/step - loss: 156.5353 - val_loss: 150.1202
#
# Epoch 00028: val_loss improved from 156.50386 to 150.12022, saving model to newModel/arrTemperature0_training_time_0_best_model_fold_0_config_8_4_2_ts100.h5
# Epoch 29/40
# 249/249 [==============================] - 0s 1ms/step - loss: 147.6053 - val_loss: 149.7085
#
# Epoch 00029: val_loss improved from 150.12022 to 149.70851, saving model to newModel/arrTemperature0_training_time_0_best_model_fold_0_config_8_4_2_ts100.h5
# Epoch 30/40
# 249/249 [==============================] - 0s 1ms/step - loss: 140.3759 - val_loss: 148.9658
#
# Epoch 00030: val_loss improved from 149.70851 to 148.96576, saving model to newModel/arrTemperature0_training_time_0_best_model_fold_0_config_8_4_2_ts100.h5
# Epoch 31/40
# 249/249 [==============================] - 0s 1ms/step - loss: 134.6197 - val_loss: 146.7879
#
# Epoch 00031: val_loss improved from 148.96576 to 146.78795, saving model to newModel/arrTemperature0_training_time_0_best_model_fold_0_config_8_4_2_ts100.h5
# Epoch 32/40
# 249/249 [==============================] - 0s 1ms/step - loss: 130.4909 - val_loss: 144.8781
#
# Epoch 00032: val_loss improved from 146.78795 to 144.87808, saving model to newModel/arrTemperature0_training_time_0_best_model_fold_0_config_8_4_2_ts100.h5
# Epoch 33/40
# 249/249 [==============================] - 0s 1ms/step - loss: 125.9404 - val_loss: 138.2502
#
# Epoch 00033: val_loss improved from 144.87808 to 138.25023, saving model to newModel/arrTemperature0_training_time_0_best_model_fold_0_config_8_4_2_ts100.h5
# Epoch 34/40
# 249/249 [==============================] - 0s 1ms/step - loss: 121.9938 - val_loss: 134.1187
#
# Epoch 00034: val_loss improved from 138.25023 to 134.11866, saving model to newModel/arrTemperature0_training_time_0_best_model_fold_0_config_8_4_2_ts100.h5
# Epoch 35/40
# 249/249 [==============================] - 0s 1ms/step - loss: 118.7238 - val_loss: 131.6137
#
# Epoch 00035: val_loss improved from 134.11866 to 131.61373, saving model to newModel/arrTemperature0_training_time_0_best_model_fold_0_config_8_4_2_ts100.h5
# Epoch 36/40
# 249/249 [==============================] - 0s 1ms/step - loss: 115.7946 - val_loss: 128.9474
#
# Epoch 00036: val_loss improved from 131.61373 to 128.94737, saving model to newModel/arrTemperature0_training_time_0_best_model_fold_0_config_8_4_2_ts100.h5
# Epoch 37/40
# 249/249 [==============================] - 0s 1ms/step - loss: 113.3996 - val_loss: 127.6049
#
# Epoch 00037: val_loss improved from 128.94737 to 127.60488, saving model to newModel/arrTemperature0_training_time_0_best_model_fold_0_config_8_4_2_ts100.h5
# Epoch 38/40
# 249/249 [==============================] - 0s 1ms/step - loss: 111.0577 - val_loss: 125.5175
#
# Epoch 00038: val_loss improved from 127.60488 to 125.51749, saving model to newModel/arrTemperature0_training_time_0_best_model_fold_0_config_8_4_2_ts100.h5
# Epoch 39/40
# 249/249 [==============================] - 0s 1ms/step - loss: 109.0726 - val_loss: 123.6875
#
# Epoch 00039: val_loss improved from 125.51749 to 123.68746, saving model to newModel/arrTemperature0_training_time_0_best_model_fold_0_config_8_4_2_ts100.h5
# Epoch 40/40
# 249/249 [==============================] - 0s 1ms/step - loss: 107.7497 - val_loss: 121.6029
#
# Epoch 00040: val_loss improved from 123.68746 to 121.60294, saving model to newModel/arrTemperature0_training_time_0_best_model_fold_0_config_8_4_2_ts100.h5
# 63/63 [==============================] - 0s 3ms/step
# Train on 249 samples, validate on 63 samples
# Epoch 1/40
# 249/249 [==============================] - 1s 5ms/step - loss: 3414.0860 - val_loss: 3842.4778
#
# Epoch 00001: val_loss improved from inf to 3842.47778, saving model to newModel/arrTemperature0_training_time_0_best_model_fold_1_config_8_4_2_ts100.h5
# Epoch 2/40
# 249/249 [==============================] - 0s 1ms/step - loss: 3411.6642 - val_loss: 3839.2952
#
# Epoch 00002: val_loss improved from 3842.47778 to 3839.29520, saving model to newModel/arrTemperature0_training_time_0_best_model_fold_1_config_8_4_2_ts100.h5
# Epoch 3/40
# 249/249 [==============================] - 0s 1ms/step - loss: 3407.1063 - val_loss: 3833.5679
#
# Epoch 00003: val_loss improved from 3839.29520 to 3833.56786, saving model to newModel/arrTemperature0_training_time_0_best_model_fold_1_config_8_4_2_ts100.h5
# Epoch 4/40
# 249/249 [==============================] - 0s 1ms/step - loss: 3399.6291 - val_loss: 3825.3849
#
# Epoch 00004: val_loss improved from 3833.56786 to 3825.38495, saving model to newModel/arrTemperature0_training_time_0_best_model_fold_1_config_8_4_2_ts100.h5
# Epoch 5/40
# 249/249 [==============================] - 0s 1ms/step - loss: 3388.0491 - val_loss: 3812.0117
#
# Epoch 00005: val_loss improved from 3825.38495 to 3812.01166, saving model to newModel/arrTemperature0_training_time_0_best_model_fold_1_config_8_4_2_ts100.h5
# Epoch 6/40
# 249/249 [==============================] - 0s 1ms/step - loss: 3369.6119 - val_loss: 3787.7355
#
# Epoch 00006: val_loss improved from 3812.01166 to 3787.73550, saving model to newModel/arrTemperature0_training_time_0_best_model_fold_1_config_8_4_2_ts100.h5
# Epoch 7/40
# 249/249 [==============================] - 0s 1ms/step - loss: 3339.0553 - val_loss: 3736.7044
#
# Epoch 00007: val_loss improved from 3787.73550 to 3736.70442, saving model to newModel/arrTemperature0_training_time_0_best_model_fold_1_config_8_4_2_ts100.h5
# Epoch 8/40
# 249/249 [==============================] - 0s 1ms/step - loss: 3277.2024 - val_loss: 3646.2924
#
# Epoch 00008: val_loss improved from 3736.70442 to 3646.29235, saving model to newModel/arrTemperature0_training_time_0_best_model_fold_1_config_8_4_2_ts100.h5
# Epoch 9/40
# 249/249 [==============================] - 0s 1ms/step - loss: 3185.2024 - val_loss: 3521.6307
#
# Epoch 00009: val_loss improved from 3646.29235 to 3521.63066, saving model to newModel/arrTemperature0_training_time_0_best_model_fold_1_config_8_4_2_ts100.h5
# Epoch 10/40
# 249/249 [==============================] - 0s 1ms/step - loss: 3053.6816 - val_loss: 3365.6010
#
# Epoch 00010: val_loss improved from 3521.63066 to 3365.60103, saving model to newModel/arrTemperature0_training_time_0_best_model_fold_1_config_8_4_2_ts100.h5
# Epoch 11/40
# 249/249 [==============================] - 0s 1ms/step - loss: 2881.5746 - val_loss: 3161.1639
#
# Epoch 00011: val_loss improved from 3365.60103 to 3161.16391, saving model to newModel/arrTemperature0_training_time_0_best_model_fold_1_config_8_4_2_ts100.h5
# Epoch 12/40
# 249/249 [==============================] - 0s 1ms/step - loss: 2676.8742 - val_loss: 2923.1054
#
# Epoch 00012: val_loss improved from 3161.16391 to 2923.10544, saving model to newModel/arrTemperature0_training_time_0_best_model_fold_1_config_8_4_2_ts100.h5
# Epoch 13/40
# 249/249 [==============================] - 0s 1ms/step - loss: 2451.2022 - val_loss: 2672.9798
#
# Epoch 00013: val_loss improved from 2923.10544 to 2672.97981, saving model to newModel/arrTemperature0_training_time_0_best_model_fold_1_config_8_4_2_ts100.h5
# Epoch 14/40
# 249/249 [==============================] - 0s 1ms/step - loss: 2225.3233 - val_loss: 2423.3672
#
# Epoch 00014: val_loss improved from 2672.97981 to 2423.36716, saving model to newModel/arrTemperature0_training_time_0_best_model_fold_1_config_8_4_2_ts100.h5
# Epoch 15/40
# 249/249 [==============================] - 0s 1ms/step - loss: 1999.5593 - val_loss: 2179.7827
#
# Epoch 00015: val_loss improved from 2423.36716 to 2179.78266, saving model to newModel/arrTemperature0_training_time_0_best_model_fold_1_config_8_4_2_ts100.h5
# Epoch 16/40
# 249/249 [==============================] - 0s 1ms/step - loss: 1784.1548 - val_loss: 1941.0509
#
# Epoch 00016: val_loss improved from 2179.78266 to 1941.05091, saving model to newModel/arrTemperature0_training_time_0_best_model_fold_1_config_8_4_2_ts100.h5
# Epoch 17/40
# 249/249 [==============================] - 0s 1ms/step - loss: 1576.2155 - val_loss: 1712.6445
#
# Epoch 00017: val_loss improved from 1941.05091 to 1712.64451, saving model to newModel/arrTemperature0_training_time_0_best_model_fold_1_config_8_4_2_ts100.h5
# Epoch 18/40
# 249/249 [==============================] - 0s 1ms/step - loss: 1377.8774 - val_loss: 1500.6838
#
# Epoch 00018: val_loss improved from 1712.64451 to 1500.68379, saving model to newModel/arrTemperature0_training_time_0_best_model_fold_1_config_8_4_2_ts100.h5
# Epoch 19/40
# 249/249 [==============================] - 0s 1ms/step - loss: 1198.8901 - val_loss: 1303.3910
#
# Epoch 00019: val_loss improved from 1500.68379 to 1303.39105, saving model to newModel/arrTemperature0_training_time_0_best_model_fold_1_config_8_4_2_ts100.h5
# Epoch 20/40
# 249/249 [==============================] - 0s 1ms/step - loss: 1036.3395 - val_loss: 1125.1999
#
# Epoch 00020: val_loss improved from 1303.39105 to 1125.19994, saving model to newModel/arrTemperature0_training_time_0_best_model_fold_1_config_8_4_2_ts100.h5
# Epoch 21/40
# 249/249 [==============================] - 0s 1ms/step - loss: 889.6964 - val_loss: 969.7596
#
# Epoch 00021: val_loss improved from 1125.19994 to 969.75963, saving model to newModel/arrTemperature0_training_time_0_best_model_fold_1_config_8_4_2_ts100.h5
# Epoch 22/40
# 249/249 [==============================] - 0s 1ms/step - loss: 763.8671 - val_loss: 833.8454
#
# Epoch 00022: val_loss improved from 969.75963 to 833.84537, saving model to newModel/arrTemperature0_training_time_0_best_model_fold_1_config_8_4_2_ts100.h5
# Epoch 23/40
# 249/249 [==============================] - 0s 1ms/step - loss: 659.9921 - val_loss: 715.6829
#
# Epoch 00023: val_loss improved from 833.84537 to 715.68295, saving model to newModel/arrTemperature0_training_time_0_best_model_fold_1_config_8_4_2_ts100.h5
# Epoch 24/40
# 249/249 [==============================] - 0s 1ms/step - loss: 568.9925 - val_loss: 618.1976
#
# Epoch 00024: val_loss improved from 715.68295 to 618.19759, saving model to newModel/arrTemperature0_training_time_0_best_model_fold_1_config_8_4_2_ts100.h5
# Epoch 25/40
# 249/249 [==============================] - 0s 1ms/step - loss: 496.5324 - val_loss: 537.2109
#
# Epoch 00025: val_loss improved from 618.19759 to 537.21093, saving model to newModel/arrTemperature0_training_time_0_best_model_fold_1_config_8_4_2_ts100.h5
# Epoch 26/40
# 249/249 [==============================] - 0s 1ms/step - loss: 437.8914 - val_loss: 471.7498
#
# Epoch 00026: val_loss improved from 537.21093 to 471.74983, saving model to newModel/arrTemperature0_training_time_0_best_model_fold_1_config_8_4_2_ts100.h5
# Epoch 27/40
# 249/249 [==============================] - 0s 1ms/step - loss: 393.4750 - val_loss: 418.4472
#
# Epoch 00027: val_loss improved from 471.74983 to 418.44720, saving model to newModel/arrTemperature0_training_time_0_best_model_fold_1_config_8_4_2_ts100.h5
# Epoch 28/40
# 249/249 [==============================] - 0s 1ms/step - loss: 358.0677 - val_loss: 376.5257
#
# Epoch 00028: val_loss improved from 418.44720 to 376.52569, saving model to newModel/arrTemperature0_training_time_0_best_model_fold_1_config_8_4_2_ts100.h5
# Epoch 29/40
# 249/249 [==============================] - 0s 1ms/step - loss: 330.2766 - val_loss: 343.9579
#
# Epoch 00029: val_loss improved from 376.52569 to 343.95793, saving model to newModel/arrTemperature0_training_time_0_best_model_fold_1_config_8_4_2_ts100.h5
# Epoch 30/40
# 249/249 [==============================] - 0s 1ms/step - loss: 310.5713 - val_loss: 317.3069
#
# Epoch 00030: val_loss improved from 343.95793 to 317.30691, saving model to newModel/arrTemperature0_training_time_0_best_model_fold_1_config_8_4_2_ts100.h5
# Epoch 31/40
# 249/249 [==============================] - 0s 1ms/step - loss: 293.0029 - val_loss: 295.7854
#
# Epoch 00031: val_loss improved from 317.30691 to 295.78540, saving model to newModel/arrTemperature0_training_time_0_best_model_fold_1_config_8_4_2_ts100.h5
# Epoch 32/40
# 249/249 [==============================] - 0s 1ms/step - loss: 303.3171 - val_loss: 276.0502
#
# Epoch 00032: val_loss improved from 295.78540 to 276.05025, saving model to newModel/arrTemperature0_training_time_0_best_model_fold_1_config_8_4_2_ts100.h5
# Epoch 33/40
# 249/249 [==============================] - 0s 1ms/step - loss: 329.9608 - val_loss: 263.1554
#
# Epoch 00033: val_loss improved from 276.05025 to 263.15545, saving model to newModel/arrTemperature0_training_time_0_best_model_fold_1_config_8_4_2_ts100.h5
# Epoch 34/40
# 249/249 [==============================] - 0s 1ms/step - loss: 256.8691 - val_loss: 253.4841
#
# Epoch 00034: val_loss improved from 263.15545 to 253.48410, saving model to newModel/arrTemperature0_training_time_0_best_model_fold_1_config_8_4_2_ts100.h5
# Epoch 35/40
# 249/249 [==============================] - 0s 1ms/step - loss: 252.1075 - val_loss: 242.7356
#
# Epoch 00035: val_loss improved from 253.48410 to 242.73561, saving model to newModel/arrTemperature0_training_time_0_best_model_fold_1_config_8_4_2_ts100.h5
# Epoch 36/40
# 249/249 [==============================] - 0s 1ms/step - loss: 240.3073 - val_loss: 228.2965
#
# Epoch 00036: val_loss improved from 242.73561 to 228.29649, saving model to newModel/arrTemperature0_training_time_0_best_model_fold_1_config_8_4_2_ts100.h5
# Epoch 37/40
# 249/249 [==============================] - 0s 1ms/step - loss: 220.3682 - val_loss: 211.8580
#
# Epoch 00037: val_loss improved from 228.29649 to 211.85801, saving model to newModel/arrTemperature0_training_time_0_best_model_fold_1_config_8_4_2_ts100.h5
# Epoch 38/40
# 249/249 [==============================] - 0s 1ms/step - loss: 200.9377 - val_loss: 199.7664
#
# Epoch 00038: val_loss improved from 211.85801 to 199.76639, saving model to newModel/arrTemperature0_training_time_0_best_model_fold_1_config_8_4_2_ts100.h5
# Epoch 39/40
# 249/249 [==============================] - 0s 1ms/step - loss: 180.6344 - val_loss: 186.9759
#
# Epoch 00039: val_loss improved from 199.76639 to 186.97586, saving model to newModel/arrTemperature0_training_time_0_best_model_fold_1_config_8_4_2_ts100.h5
# Epoch 40/40
# 249/249 [==============================] - 0s 1ms/step - loss: 173.6800 - val_loss: 173.6721
#
# Epoch 00040: val_loss improved from 186.97586 to 173.67207, saving model to newModel/arrTemperature0_training_time_0_best_model_fold_1_config_8_4_2_ts100.h5
# 63/63 [==============================] - 0s 6ms/step
# Train on 250 samples, validate on 62 samples
# Epoch 1/40
# 250/250 [==============================] - 1s 6ms/step - loss: 3452.3364 - val_loss: 3419.1717
#
# Epoch 00001: val_loss improved from inf to 3419.17167, saving model to newModel/arrTemperature0_training_time_0_best_model_fold_2_config_8_4_2_ts100.h5
# Epoch 2/40
# 250/250 [==============================] - 0s 1ms/step - loss: 3374.1811 - val_loss: 3316.1212
#
# Epoch 00002: val_loss improved from 3419.17167 to 3316.12120, saving model to newModel/arrTemperature0_training_time_0_best_model_fold_2_config_8_4_2_ts100.h5
# Epoch 3/40
# 250/250 [==============================] - 0s 1ms/step - loss: 3235.0747 - val_loss: 3134.1367
#
# Epoch 00003: val_loss improved from 3316.12120 to 3134.13667, saving model to newModel/arrTemperature0_training_time_0_best_model_fold_2_config_8_4_2_ts100.h5
# Epoch 4/40
# 250/250 [==============================] - 0s 1ms/step - loss: 3016.3190 - val_loss: 2865.9595
#
# Epoch 00004: val_loss improved from 3134.13667 to 2865.95952, saving model to newModel/arrTemperature0_training_time_0_best_model_fold_2_config_8_4_2_ts100.h5
# Epoch 5/40
# 250/250 [==============================] - 0s 1ms/step - loss: 2726.2085 - val_loss: 2522.2552
#
# Epoch 00005: val_loss improved from 2865.95952 to 2522.25523, saving model to newModel/arrTemperature0_training_time_0_best_model_fold_2_config_8_4_2_ts100.h5
# Epoch 6/40
# 250/250 [==============================] - 0s 1ms/step - loss: 2348.2163 - val_loss: 2116.6643
#
# Epoch 00006: val_loss improved from 2522.25523 to 2116.66433, saving model to newModel/arrTemperature0_training_time_0_best_model_fold_2_config_8_4_2_ts100.h5
# Epoch 7/40
# 250/250 [==============================] - 0s 1ms/step - loss: 1883.2363 - val_loss: 1650.7212
#
# Epoch 00007: val_loss improved from 2116.66433 to 1650.72116, saving model to newModel/arrTemperature0_training_time_0_best_model_fold_2_config_8_4_2_ts100.h5
# Epoch 8/40
# 250/250 [==============================] - 0s 1ms/step - loss: 1393.4170 - val_loss: 1105.8438
#
# Epoch 00008: val_loss improved from 1650.72116 to 1105.84381, saving model to newModel/arrTemperature0_training_time_0_best_model_fold_2_config_8_4_2_ts100.h5
# Epoch 9/40
# 250/250 [==============================] - 0s 1ms/step - loss: 904.6382 - val_loss: 663.7805
#
# Epoch 00009: val_loss improved from 1105.84381 to 663.78049, saving model to newModel/arrTemperature0_training_time_0_best_model_fold_2_config_8_4_2_ts100.h5
# Epoch 10/40
# 250/250 [==============================] - 0s 1ms/step - loss: 540.4638 - val_loss: 417.1852
#
# Epoch 00010: val_loss improved from 663.78049 to 417.18520, saving model to newModel/arrTemperature0_training_time_0_best_model_fold_2_config_8_4_2_ts100.h5
# Epoch 11/40
# 250/250 [==============================] - 0s 1ms/step - loss: 339.6527 - val_loss: 298.6821
#
# Epoch 00011: val_loss improved from 417.18520 to 298.68214, saving model to newModel/arrTemperature0_training_time_0_best_model_fold_2_config_8_4_2_ts100.h5
# Epoch 12/40
# 250/250 [==============================] - 0s 1ms/step - loss: 242.8030 - val_loss: 246.5212
#
# Epoch 00012: val_loss improved from 298.68214 to 246.52122, saving model to newModel/arrTemperature0_training_time_0_best_model_fold_2_config_8_4_2_ts100.h5
# Epoch 13/40
# 250/250 [==============================] - 0s 1ms/step - loss: 199.0742 - val_loss: 220.8498
#
# Epoch 00013: val_loss improved from 246.52122 to 220.84980, saving model to newModel/arrTemperature0_training_time_0_best_model_fold_2_config_8_4_2_ts100.h5
# Epoch 14/40
# 250/250 [==============================] - 0s 1ms/step - loss: 170.2922 - val_loss: 194.1321
#
# Epoch 00014: val_loss improved from 220.84980 to 194.13212, saving model to newModel/arrTemperature0_training_time_0_best_model_fold_2_config_8_4_2_ts100.h5
# Epoch 15/40
# 250/250 [==============================] - 0s 1ms/step - loss: 147.7906 - val_loss: 171.0629
#
# Epoch 00015: val_loss improved from 194.13212 to 171.06294, saving model to newModel/arrTemperature0_training_time_0_best_model_fold_2_config_8_4_2_ts100.h5
# Epoch 16/40
# 250/250 [==============================] - 0s 1ms/step - loss: 133.5467 - val_loss: 154.4692
#
# Epoch 00016: val_loss improved from 171.06294 to 154.46925, saving model to newModel/arrTemperature0_training_time_0_best_model_fold_2_config_8_4_2_ts100.h5
# Epoch 17/40
# 250/250 [==============================] - 0s 1ms/step - loss: 125.0399 - val_loss: 139.3515
#
# Epoch 00017: val_loss improved from 154.46925 to 139.35148, saving model to newModel/arrTemperature0_training_time_0_best_model_fold_2_config_8_4_2_ts100.h5
# Epoch 18/40
# 250/250 [==============================] - 0s 1ms/step - loss: 119.1434 - val_loss: 126.8119
#
# Epoch 00018: val_loss improved from 139.35148 to 126.81192, saving model to newModel/arrTemperature0_training_time_0_best_model_fold_2_config_8_4_2_ts100.h5
# Epoch 19/40
# 250/250 [==============================] - 0s 1ms/step - loss: 113.3225 - val_loss: 119.7212
#
# Epoch 00019: val_loss improved from 126.81192 to 119.72118, saving model to newModel/arrTemperature0_training_time_0_best_model_fold_2_config_8_4_2_ts100.h5
# Epoch 20/40
# 250/250 [==============================] - 0s 1ms/step - loss: 109.2220 - val_loss: 118.8247
#
# Epoch 00020: val_loss improved from 119.72118 to 118.82467, saving model to newModel/arrTemperature0_training_time_0_best_model_fold_2_config_8_4_2_ts100.h5
# Epoch 21/40
# 250/250 [==============================] - 0s 1ms/step - loss: 105.8072 - val_loss: 120.6252
#
# Epoch 00021: val_loss did not improve from 118.82467
# Epoch 22/40
# 250/250 [==============================] - 0s 1ms/step - loss: 103.2822 - val_loss: 120.4901
#
# Epoch 00022: val_loss did not improve from 118.82467
# Epoch 23/40
# 250/250 [==============================] - 0s 1ms/step - loss: 100.8327 - val_loss: 119.1483
#
# Epoch 00023: val_loss did not improve from 118.82467
# Epoch 00023: early stopping
# 62/62 [==============================] - 0s 8ms/step
# Train on 250 samples, validate on 62 samples
# Epoch 1/40
# 250/250 [==============================] - 2s 6ms/step - loss: 3535.8837 - val_loss: 3320.5267
#
# Epoch 00001: val_loss improved from inf to 3320.52666, saving model to newModel/arrTemperature0_training_time_0_best_model_fold_3_config_8_4_2_ts100.h5
# Epoch 2/40
# 250/250 [==============================] - 0s 1ms/step - loss: 3519.4083 - val_loss: 3304.0019
#
# Epoch 00002: val_loss improved from 3320.52666 to 3304.00187, saving model to newModel/arrTemperature0_training_time_0_best_model_fold_3_config_8_4_2_ts100.h5
# Epoch 3/40
# 250/250 [==============================] - 0s 1ms/step - loss: 3492.0103 - val_loss: 3274.7762
#
# Epoch 00003: val_loss improved from 3304.00187 to 3274.77617, saving model to newModel/arrTemperature0_training_time_0_best_model_fold_3_config_8_4_2_ts100.h5
# Epoch 4/40
# 250/250 [==============================] - 0s 1ms/step - loss: 3447.5358 - val_loss: 3224.5512
#
# Epoch 00004: val_loss improved from 3274.77617 to 3224.55119, saving model to newModel/arrTemperature0_training_time_0_best_model_fold_3_config_8_4_2_ts100.h5
# Epoch 5/40
# 250/250 [==============================] - 0s 1ms/step - loss: 3377.6734 - val_loss: 3145.3914
#
# Epoch 00005: val_loss improved from 3224.55119 to 3145.39142, saving model to newModel/arrTemperature0_training_time_0_best_model_fold_3_config_8_4_2_ts100.h5
# Epoch 6/40
# 250/250 [==============================] - 0s 1ms/step - loss: 3274.3599 - val_loss: 3033.1216
#
# Epoch 00006: val_loss improved from 3145.39142 to 3033.12161, saving model to newModel/arrTemperature0_training_time_0_best_model_fold_3_config_8_4_2_ts100.h5
# Epoch 7/40
# 250/250 [==============================] - 0s 1ms/step - loss: 3136.7282 - val_loss: 2888.5909
#
# Epoch 00007: val_loss improved from 3033.12161 to 2888.59091, saving model to newModel/arrTemperature0_training_time_0_best_model_fold_3_config_8_4_2_ts100.h5
# Epoch 8/40
# 250/250 [==============================] - 0s 1ms/step - loss: 2964.8777 - val_loss: 2715.3391
#
# Epoch 00008: val_loss improved from 2888.59091 to 2715.33913, saving model to newModel/arrTemperature0_training_time_0_best_model_fold_3_config_8_4_2_ts100.h5
# Epoch 9/40
# 250/250 [==============================] - 0s 1ms/step - loss: 2759.8731 - val_loss: 2509.6265
#
# Epoch 00009: val_loss improved from 2715.33913 to 2509.62646, saving model to newModel/arrTemperature0_training_time_0_best_model_fold_3_config_8_4_2_ts100.h5
# Epoch 10/40
# 250/250 [==============================] - 0s 1ms/step - loss: 2511.9934 - val_loss: 2263.7630
#
# Epoch 00010: val_loss improved from 2509.62646 to 2263.76304, saving model to newModel/arrTemperature0_training_time_0_best_model_fold_3_config_8_4_2_ts100.h5
# Epoch 11/40
# 250/250 [==============================] - 0s 1ms/step - loss: 2230.8346 - val_loss: 1960.2702
#
# Epoch 00011: val_loss improved from 2263.76304 to 1960.27019, saving model to newModel/arrTemperature0_training_time_0_best_model_fold_3_config_8_4_2_ts100.h5
# Epoch 12/40
# 250/250 [==============================] - 0s 1ms/step - loss: 1936.4012 - val_loss: 1656.5366
#
# Epoch 00012: val_loss improved from 1960.27019 to 1656.53659, saving model to newModel/arrTemperature0_training_time_0_best_model_fold_3_config_8_4_2_ts100.h5
# Epoch 13/40
# 250/250 [==============================] - 0s 1ms/step - loss: 1622.3744 - val_loss: 1377.7010
#
# Epoch 00013: val_loss improved from 1656.53659 to 1377.70102, saving model to newModel/arrTemperature0_training_time_0_best_model_fold_3_config_8_4_2_ts100.h5
# Epoch 14/40
# 250/250 [==============================] - 0s 1ms/step - loss: 1312.6608 - val_loss: 1126.1310
#
# Epoch 00014: val_loss improved from 1377.70102 to 1126.13100, saving model to newModel/arrTemperature0_training_time_0_best_model_fold_3_config_8_4_2_ts100.h5
# Epoch 15/40
# 250/250 [==============================] - 0s 1ms/step - loss: 1041.9094 - val_loss: 908.3250
#
# Epoch 00015: val_loss improved from 1126.13100 to 908.32498, saving model to newModel/arrTemperature0_training_time_0_best_model_fold_3_config_8_4_2_ts100.h5
# Epoch 16/40
# 250/250 [==============================] - 0s 1ms/step - loss: 816.9659 - val_loss: 705.4183
#
# Epoch 00016: val_loss improved from 908.32498 to 705.41826, saving model to newModel/arrTemperature0_training_time_0_best_model_fold_3_config_8_4_2_ts100.h5
# Epoch 17/40
# 250/250 [==============================] - 0s 1ms/step - loss: 630.5405 - val_loss: 531.2061
#
# Epoch 00017: val_loss improved from 705.41826 to 531.20607, saving model to newModel/arrTemperature0_training_time_0_best_model_fold_3_config_8_4_2_ts100.h5
# Epoch 18/40
# 250/250 [==============================] - 0s 1ms/step - loss: 488.4240 - val_loss: 401.7155
#
# Epoch 00018: val_loss improved from 531.20607 to 401.71554, saving model to newModel/arrTemperature0_training_time_0_best_model_fold_3_config_8_4_2_ts100.h5
# Epoch 19/40
# 250/250 [==============================] - 0s 1ms/step - loss: 382.3177 - val_loss: 311.8921
#
# Epoch 00019: val_loss improved from 401.71554 to 311.89215, saving model to newModel/arrTemperature0_training_time_0_best_model_fold_3_config_8_4_2_ts100.h5
# Epoch 20/40
# 250/250 [==============================] - 0s 1ms/step - loss: 311.0707 - val_loss: 251.6569
#
# Epoch 00020: val_loss improved from 311.89215 to 251.65693, saving model to newModel/arrTemperature0_training_time_0_best_model_fold_3_config_8_4_2_ts100.h5
# Epoch 21/40
# 250/250 [==============================] - 0s 1ms/step - loss: 262.3326 - val_loss: 213.1806
#
# Epoch 00021: val_loss improved from 251.65693 to 213.18061, saving model to newModel/arrTemperature0_training_time_0_best_model_fold_3_config_8_4_2_ts100.h5
# Epoch 22/40
# 250/250 [==============================] - 0s 1ms/step - loss: 231.5287 - val_loss: 188.2110
#
# Epoch 00022: val_loss improved from 213.18061 to 188.21102, saving model to newModel/arrTemperature0_training_time_0_best_model_fold_3_config_8_4_2_ts100.h5
# Epoch 23/40
# 250/250 [==============================] - 0s 1ms/step - loss: 209.3479 - val_loss: 169.9320
#
# Epoch 00023: val_loss improved from 188.21102 to 169.93201, saving model to newModel/arrTemperature0_training_time_0_best_model_fold_3_config_8_4_2_ts100.h5
# Epoch 24/40
# 250/250 [==============================] - 0s 1ms/step - loss: 193.0390 - val_loss: 153.0962
#
# Epoch 00024: val_loss improved from 169.93201 to 153.09618, saving model to newModel/arrTemperature0_training_time_0_best_model_fold_3_config_8_4_2_ts100.h5
# Epoch 25/40
# 250/250 [==============================] - 0s 1ms/step - loss: 176.9899 - val_loss: 135.6989
#
# Epoch 00025: val_loss improved from 153.09618 to 135.69888, saving model to newModel/arrTemperature0_training_time_0_best_model_fold_3_config_8_4_2_ts100.h5
# Epoch 26/40
# 250/250 [==============================] - 0s 1ms/step - loss: 161.6493 - val_loss: 119.7509
#
# Epoch 00026: val_loss improved from 135.69888 to 119.75087, saving model to newModel/arrTemperature0_training_time_0_best_model_fold_3_config_8_4_2_ts100.h5
# Epoch 27/40
# 250/250 [==============================] - 0s 1ms/step - loss: 148.6217 - val_loss: 107.8677
#
# Epoch 00027: val_loss improved from 119.75087 to 107.86768, saving model to newModel/arrTemperature0_training_time_0_best_model_fold_3_config_8_4_2_ts100.h5
# Epoch 28/40
# 250/250 [==============================] - 0s 1ms/step - loss: 139.5778 - val_loss: 104.4107
#
# Epoch 00028: val_loss improved from 107.86768 to 104.41074, saving model to newModel/arrTemperature0_training_time_0_best_model_fold_3_config_8_4_2_ts100.h5
# Epoch 29/40
# 250/250 [==============================] - 0s 1ms/step - loss: 130.9318 - val_loss: 99.8962
#
# Epoch 00029: val_loss improved from 104.41074 to 99.89621, saving model to newModel/arrTemperature0_training_time_0_best_model_fold_3_config_8_4_2_ts100.h5
# Epoch 30/40
# 250/250 [==============================] - 0s 1ms/step - loss: 124.3105 - val_loss: 94.6391
#
# Epoch 00030: val_loss improved from 99.89621 to 94.63906, saving model to newModel/arrTemperature0_training_time_0_best_model_fold_3_config_8_4_2_ts100.h5
# Epoch 31/40
# 250/250 [==============================] - 0s 1ms/step - loss: 119.6436 - val_loss: 91.8450
#
# Epoch 00031: val_loss improved from 94.63906 to 91.84496, saving model to newModel/arrTemperature0_training_time_0_best_model_fold_3_config_8_4_2_ts100.h5
# Epoch 32/40
# 250/250 [==============================] - 0s 1ms/step - loss: 115.5831 - val_loss: 90.1121
#
# Epoch 00032: val_loss improved from 91.84496 to 90.11208, saving model to newModel/arrTemperature0_training_time_0_best_model_fold_3_config_8_4_2_ts100.h5
# Epoch 33/40
# 250/250 [==============================] - 0s 1ms/step - loss: 112.3056 - val_loss: 88.5830
#
# Epoch 00033: val_loss improved from 90.11208 to 88.58303, saving model to newModel/arrTemperature0_training_time_0_best_model_fold_3_config_8_4_2_ts100.h5
# Epoch 34/40
# 250/250 [==============================] - 0s 1ms/step - loss: 108.9276 - val_loss: 87.8850
#
# Epoch 00034: val_loss improved from 88.58303 to 87.88504, saving model to newModel/arrTemperature0_training_time_0_best_model_fold_3_config_8_4_2_ts100.h5
# Epoch 35/40
# 250/250 [==============================] - 0s 1ms/step - loss: 106.7213 - val_loss: 87.2518
#
# Epoch 00035: val_loss improved from 87.88504 to 87.25181, saving model to newModel/arrTemperature0_training_time_0_best_model_fold_3_config_8_4_2_ts100.h5
# Epoch 36/40
# 250/250 [==============================] - 0s 1ms/step - loss: 104.2788 - val_loss: 86.5879
#
# Epoch 00036: val_loss improved from 87.25181 to 86.58786, saving model to newModel/arrTemperature0_training_time_0_best_model_fold_3_config_8_4_2_ts100.h5
# Epoch 37/40
# 250/250 [==============================] - 0s 1ms/step - loss: 102.5202 - val_loss: 85.7164
#
# Epoch 00037: val_loss improved from 86.58786 to 85.71643, saving model to newModel/arrTemperature0_training_time_0_best_model_fold_3_config_8_4_2_ts100.h5
# Epoch 38/40
# 250/250 [==============================] - 0s 1ms/step - loss: 100.3192 - val_loss: 85.0774
#
# Epoch 00038: val_loss improved from 85.71643 to 85.07742, saving model to newModel/arrTemperature0_training_time_0_best_model_fold_3_config_8_4_2_ts100.h5
# Epoch 39/40
# 250/250 [==============================] - 0s 1ms/step - loss: 98.5351 - val_loss: 84.4776
#
# Epoch 00039: val_loss improved from 85.07742 to 84.47759, saving model to newModel/arrTemperature0_training_time_0_best_model_fold_3_config_8_4_2_ts100.h5
# Epoch 40/40
# 250/250 [==============================] - 0s 1ms/step - loss: 96.7376 - val_loss: 83.6377
#
# Epoch 00040: val_loss improved from 84.47759 to 83.63773, saving model to newModel/arrTemperature0_training_time_0_best_model_fold_3_config_8_4_2_ts100.h5
# 62/62 [==============================] - 1s 11ms/step
# Train on 250 samples, validate on 62 samples
# Epoch 1/40
# 250/250 [==============================] - 2s 7ms/step - loss: 3477.4498 - val_loss: 3539.4214
#
# Epoch 00001: val_loss improved from inf to 3539.42140, saving model to newModel/arrTemperature0_training_time_0_best_model_fold_4_config_8_4_2_ts100.h5
# Epoch 2/40
# 250/250 [==============================] - 0s 1ms/step - loss: 3450.8245 - val_loss: 3514.3431
#
# Epoch 00002: val_loss improved from 3539.42140 to 3514.34312, saving model to newModel/arrTemperature0_training_time_0_best_model_fold_4_config_8_4_2_ts100.h5
# Epoch 3/40
# 250/250 [==============================] - 0s 1ms/step - loss: 3411.2824 - val_loss: 3476.7803
#
# Epoch 00003: val_loss improved from 3514.34312 to 3476.78030, saving model to newModel/arrTemperature0_training_time_0_best_model_fold_4_config_8_4_2_ts100.h5
# Epoch 4/40
# 250/250 [==============================] - 0s 1ms/step - loss: 3355.4963 - val_loss: 3422.7053
#
# Epoch 00004: val_loss improved from 3476.78030 to 3422.70534, saving model to newModel/arrTemperature0_training_time_0_best_model_fold_4_config_8_4_2_ts100.h5
# Epoch 5/40
# 250/250 [==============================] - 0s 1ms/step - loss: 3277.0478 - val_loss: 3349.2372
#
# Epoch 00005: val_loss improved from 3422.70534 to 3349.23716, saving model to newModel/arrTemperature0_training_time_0_best_model_fold_4_config_8_4_2_ts100.h5
# Epoch 6/40
# 250/250 [==============================] - 0s 1ms/step - loss: 3177.1520 - val_loss: 3251.3219
#
# Epoch 00006: val_loss improved from 3349.23716 to 3251.32186, saving model to newModel/arrTemperature0_training_time_0_best_model_fold_4_config_8_4_2_ts100.h5
# Epoch 7/40
# 250/250 [==============================] - 0s 1ms/step - loss: 3045.0475 - val_loss: 3127.1662
#
# Epoch 00007: val_loss improved from 3251.32186 to 3127.16616, saving model to newModel/arrTemperature0_training_time_0_best_model_fold_4_config_8_4_2_ts100.h5
# Epoch 8/40
# 250/250 [==============================] - 0s 1ms/step - loss: 2870.2645 - val_loss: 2960.6166
#
# Epoch 00008: val_loss improved from 3127.16616 to 2960.61664, saving model to newModel/arrTemperature0_training_time_0_best_model_fold_4_config_8_4_2_ts100.h5
# Epoch 9/40
# 250/250 [==============================] - 0s 1ms/step - loss: 2643.8212 - val_loss: 2684.1114
#
# Epoch 00009: val_loss improved from 2960.61664 to 2684.11139, saving model to newModel/arrTemperature0_training_time_0_best_model_fold_4_config_8_4_2_ts100.h5
# Epoch 10/40
# 250/250 [==============================] - 0s 1ms/step - loss: 2329.9564 - val_loss: 2297.5798
#
# Epoch 00010: val_loss improved from 2684.11139 to 2297.57977, saving model to newModel/arrTemperature0_training_time_0_best_model_fold_4_config_8_4_2_ts100.h5
# Epoch 11/40
# 250/250 [==============================] - 0s 1ms/step - loss: 1968.9622 - val_loss: 1912.6956
#
# Epoch 00011: val_loss improved from 2297.57977 to 1912.69562, saving model to newModel/arrTemperature0_training_time_0_best_model_fold_4_config_8_4_2_ts100.h5
# Epoch 12/40
# 250/250 [==============================] - 0s 1ms/step - loss: 1624.2184 - val_loss: 1515.1616
#
# Epoch 00012: val_loss improved from 1912.69562 to 1515.16162, saving model to newModel/arrTemperature0_training_time_0_best_model_fold_4_config_8_4_2_ts100.h5
# Epoch 13/40
# 250/250 [==============================] - 0s 1ms/step - loss: 1259.1612 - val_loss: 1151.4018
#
# Epoch 00013: val_loss improved from 1515.16162 to 1151.40183, saving model to newModel/arrTemperature0_training_time_0_best_model_fold_4_config_8_4_2_ts100.h5
# Epoch 14/40
# 250/250 [==============================] - 0s 1ms/step - loss: 946.8143 - val_loss: 872.1873
#
# Epoch 00014: val_loss improved from 1151.40183 to 872.18734, saving model to newModel/arrTemperature0_training_time_0_best_model_fold_4_config_8_4_2_ts100.h5
# Epoch 15/40
# 250/250 [==============================] - 0s 1ms/step - loss: 713.6726 - val_loss: 672.6508
#
# Epoch 00015: val_loss improved from 872.18734 to 672.65081, saving model to newModel/arrTemperature0_training_time_0_best_model_fold_4_config_8_4_2_ts100.h5
# Epoch 16/40
# 250/250 [==============================] - 0s 1ms/step - loss: 553.2996 - val_loss: 536.5781
#
# Epoch 00016: val_loss improved from 672.65081 to 536.57812, saving model to newModel/arrTemperature0_training_time_0_best_model_fold_4_config_8_4_2_ts100.h5
# Epoch 17/40
# 250/250 [==============================] - 0s 1ms/step - loss: 449.6475 - val_loss: 448.6212
#
# Epoch 00017: val_loss improved from 536.57812 to 448.62120, saving model to newModel/arrTemperature0_training_time_0_best_model_fold_4_config_8_4_2_ts100.h5
# Epoch 18/40
# 250/250 [==============================] - 0s 1ms/step - loss: 384.1037 - val_loss: 394.5163
#
# Epoch 00018: val_loss improved from 448.62120 to 394.51628, saving model to newModel/arrTemperature0_training_time_0_best_model_fold_4_config_8_4_2_ts100.h5
# Epoch 19/40
# 250/250 [==============================] - 0s 1ms/step - loss: 342.1140 - val_loss: 358.1028
#
# Epoch 00019: val_loss improved from 394.51628 to 358.10285, saving model to newModel/arrTemperature0_training_time_0_best_model_fold_4_config_8_4_2_ts100.h5
# Epoch 20/40
# 250/250 [==============================] - 0s 1ms/step - loss: 316.5510 - val_loss: 328.6171
#
# Epoch 00020: val_loss improved from 358.10285 to 328.61710, saving model to newModel/arrTemperature0_training_time_0_best_model_fold_4_config_8_4_2_ts100.h5
# Epoch 21/40
# 250/250 [==============================] - 0s 1ms/step - loss: 295.5260 - val_loss: 302.4628
#
# Epoch 00021: val_loss improved from 328.61710 to 302.46285, saving model to newModel/arrTemperature0_training_time_0_best_model_fold_4_config_8_4_2_ts100.h5
# Epoch 22/40
# 250/250 [==============================] - 0s 1ms/step - loss: 277.0067 - val_loss: 281.5125
#
# Epoch 00022: val_loss improved from 302.46285 to 281.51251, saving model to newModel/arrTemperature0_training_time_0_best_model_fold_4_config_8_4_2_ts100.h5
# Epoch 23/40
# 250/250 [==============================] - 0s 1ms/step - loss: 258.6834 - val_loss: 266.8345
#
# Epoch 00023: val_loss improved from 281.51251 to 266.83454, saving model to newModel/arrTemperature0_training_time_0_best_model_fold_4_config_8_4_2_ts100.h5
# Epoch 24/40
# 250/250 [==============================] - 0s 1ms/step - loss: 236.4312 - val_loss: 253.3593
#
# Epoch 00024: val_loss improved from 266.83454 to 253.35934, saving model to newModel/arrTemperature0_training_time_0_best_model_fold_4_config_8_4_2_ts100.h5
# Epoch 25/40
# 250/250 [==============================] - 0s 1ms/step - loss: 211.5275 - val_loss: 235.2144
#
# Epoch 00025: val_loss improved from 253.35934 to 235.21441, saving model to newModel/arrTemperature0_training_time_0_best_model_fold_4_config_8_4_2_ts100.h5
# Epoch 26/40
# 250/250 [==============================] - 0s 1ms/step - loss: 188.2685 - val_loss: 229.3394
#
# Epoch 00026: val_loss improved from 235.21441 to 229.33938, saving model to newModel/arrTemperature0_training_time_0_best_model_fold_4_config_8_4_2_ts100.h5
# Epoch 27/40
# 250/250 [==============================] - 0s 1ms/step - loss: 170.3617 - val_loss: 207.0929
#
# Epoch 00027: val_loss improved from 229.33938 to 207.09294, saving model to newModel/arrTemperature0_training_time_0_best_model_fold_4_config_8_4_2_ts100.h5
# Epoch 28/40
# 250/250 [==============================] - 0s 1ms/step - loss: 169.8974 - val_loss: 203.3996
#
# Epoch 00028: val_loss improved from 207.09294 to 203.39959, saving model to newModel/arrTemperature0_training_time_0_best_model_fold_4_config_8_4_2_ts100.h5
# Epoch 29/40
# 250/250 [==============================] - 0s 1ms/step - loss: 161.6306 - val_loss: 192.6341
#
# Epoch 00029: val_loss improved from 203.39959 to 192.63407, saving model to newModel/arrTemperature0_training_time_0_best_model_fold_4_config_8_4_2_ts100.h5
# Epoch 30/40
# 250/250 [==============================] - 0s 1ms/step - loss: 146.1564 - val_loss: 182.7916
#
# Epoch 00030: val_loss improved from 192.63407 to 182.79156, saving model to newModel/arrTemperature0_training_time_0_best_model_fold_4_config_8_4_2_ts100.h5
# Epoch 31/40
# 250/250 [==============================] - 0s 1ms/step - loss: 143.9072 - val_loss: 175.7057
#
# Epoch 00031: val_loss improved from 182.79156 to 175.70566, saving model to newModel/arrTemperature0_training_time_0_best_model_fold_4_config_8_4_2_ts100.h5
# Epoch 32/40
# 250/250 [==============================] - 0s 1ms/step - loss: 132.1557 - val_loss: 170.1714
#
# Epoch 00032: val_loss improved from 175.70566 to 170.17143, saving model to newModel/arrTemperature0_training_time_0_best_model_fold_4_config_8_4_2_ts100.h5
# Epoch 33/40
# 250/250 [==============================] - 0s 1ms/step - loss: 124.7121 - val_loss: 165.7732
#
# Epoch 00033: val_loss improved from 170.17143 to 165.77320, saving model to newModel/arrTemperature0_training_time_0_best_model_fold_4_config_8_4_2_ts100.h5
# Epoch 34/40
# 250/250 [==============================] - 0s 1ms/step - loss: 120.9718 - val_loss: 161.3708
#
# Epoch 00034: val_loss improved from 165.77320 to 161.37078, saving model to newModel/arrTemperature0_training_time_0_best_model_fold_4_config_8_4_2_ts100.h5
# Epoch 35/40
# 250/250 [==============================] - 0s 1ms/step - loss: 116.2632 - val_loss: 156.1050
#
# Epoch 00035: val_loss improved from 161.37078 to 156.10498, saving model to newModel/arrTemperature0_training_time_0_best_model_fold_4_config_8_4_2_ts100.h5
# Epoch 36/40
# 250/250 [==============================] - 0s 1ms/step - loss: 111.8139 - val_loss: 152.8975
#
# ...
# Epoch 5/40
# 250/250 [==============================] - 0s 1ms/step - loss: 3337.5116 - val_loss: 2974.9538
#
# Epoch 00005: val_loss improved from 3104.73706 to 2974.95376, saving model to newModel/arrTemperature0_training_time_2_best_model_fold_3_config_8_4_2_ts100.h5
# Epoch 6/40
# 250/250 [==============================] - 0s 1ms/step - loss: 3173.3985 - val_loss: 2783.0198
#
# Epoch 00006: val_loss improved from 2974.95376 to 2783.01984, saving model to newModel/arrTemperature0_training_time_2_best_model_fold_3_config_8_4_2_ts100.h5
# Epoch 7/40
# 250/250 [==============================] - 0s 2ms/step - loss: 2942.7898 - val_loss: 2528.1660
#
# Epoch 00007: val_loss improved from 2783.01984 to 2528.16597, saving model to newModel/arrTemperature0_training_time_2_best_model_fold_3_config_8_4_2_ts100.h5
# Epoch 8/40
# 250/250 [==============================] - 0s 1ms/step - loss: 2646.1363 - val_loss: 2227.7687
#
# Epoch 00008: val_loss improved from 2528.16597 to 2227.76868, saving model to newModel/arrTemperature0_training_time_2_best_model_fold_3_config_8_4_2_ts100.h5
# Epoch 9/40
# 250/250 [==============================] - 1s 2ms/step - loss: 2320.9092 - val_loss: 1911.5773
#
# Epoch 00009: val_loss improved from 2227.76868 to 1911.57735, saving model to newModel/arrTemperature0_training_time_2_best_model_fold_3_config_8_4_2_ts100.h5
# Epoch 10/40
# 250/250 [==============================] - 0s 2ms/step - loss: 1989.8026 - val_loss: 1608.3027
#
# Epoch 00010: val_loss improved from 1911.57735 to 1608.30270, saving model to newModel/arrTemperature0_training_time_2_best_model_fold_3_config_8_4_2_ts100.h5
# Epoch 11/40
# 250/250 [==============================] - 0s 2ms/step - loss: 1684.0184 - val_loss: 1331.4913
#
# Epoch 00011: val_loss improved from 1608.30270 to 1331.49130, saving model to newModel/arrTemperature0_training_time_2_best_model_fold_3_config_8_4_2_ts100.h5
# Epoch 12/40
# 250/250 [==============================] - 0s 1ms/step - loss: 1399.9922 - val_loss: 1086.4218
#
# Epoch 00012: val_loss improved from 1331.49130 to 1086.42183, saving model to newModel/arrTemperature0_training_time_2_best_model_fold_3_config_8_4_2_ts100.h5
# Epoch 13/40
# 250/250 [==============================] - 0s 1ms/step - loss: 1152.2511 - val_loss: 870.7274
#
# Epoch 00013: val_loss improved from 1086.42183 to 870.72736, saving model to newModel/arrTemperature0_training_time_2_best_model_fold_3_config_8_4_2_ts100.h5
# Epoch 14/40
# 250/250 [==============================] - 0s 1ms/step - loss: 931.9551 - val_loss: 687.5064
#
# Epoch 00014: val_loss improved from 870.72736 to 687.50636, saving model to newModel/arrTemperature0_training_time_2_best_model_fold_3_config_8_4_2_ts100.h5
# Epoch 15/40
# 250/250 [==============================] - 0s 1ms/step - loss: 741.1646 - val_loss: 538.4990
#
# Epoch 00015: val_loss improved from 687.50636 to 538.49900, saving model to newModel/arrTemperature0_training_time_2_best_model_fold_3_config_8_4_2_ts100.h5
# Epoch 16/40
# 250/250 [==============================] - 0s 1ms/step - loss: 590.7011 - val_loss: 419.8985
#
# Epoch 00016: val_loss improved from 538.49900 to 419.89851, saving model to newModel/arrTemperature0_training_time_2_best_model_fold_3_config_8_4_2_ts100.h5
# Epoch 17/40
# 250/250 [==============================] - 0s 1ms/step - loss: 470.1943 - val_loss: 331.2832
#
# Epoch 00017: val_loss improved from 419.89851 to 331.28322, saving model to newModel/arrTemperature0_training_time_2_best_model_fold_3_config_8_4_2_ts100.h5
# Epoch 18/40
# 250/250 [==============================] - 0s 1ms/step - loss: 377.2783 - val_loss: 270.3485
#
# Epoch 00018: val_loss improved from 331.28322 to 270.34847, saving model to newModel/arrTemperature0_training_time_2_best_model_fold_3_config_8_4_2_ts100.h5
# Epoch 19/40
# 250/250 [==============================] - 0s 2ms/step - loss: 313.4873 - val_loss: 229.7721
#
# Epoch 00019: val_loss improved from 270.34847 to 229.77209, saving model to newModel/arrTemperature0_training_time_2_best_model_fold_3_config_8_4_2_ts100.h5
# Epoch 20/40
# 250/250 [==============================] - 0s 2ms/step - loss: 267.0372 - val_loss: 204.8310
#
# Epoch 00020: val_loss improved from 229.77209 to 204.83104, saving model to newModel/arrTemperature0_training_time_2_best_model_fold_3_config_8_4_2_ts100.h5
# Epoch 21/40
# 250/250 [==============================] - 0s 1ms/step - loss: 237.9981 - val_loss: 188.8926
#
# Epoch 00021: val_loss improved from 204.83104 to 188.89258, saving model to newModel/arrTemperature0_training_time_2_best_model_fold_3_config_8_4_2_ts100.h5
# Epoch 22/40
# 250/250 [==============================] - 0s 1ms/step - loss: 220.7699 - val_loss: 176.9850
#
# Epoch 00022: val_loss improved from 188.89258 to 176.98497, saving model to newModel/arrTemperature0_training_time_2_best_model_fold_3_config_8_4_2_ts100.h5
# Epoch 23/40
# 250/250 [==============================] - 0s 1ms/step - loss: 208.0646 - val_loss: 187.7861
#
# Epoch 00023: val_loss did not improve from 176.98497
# Epoch 24/40
# 250/250 [==============================] - 0s 1ms/step - loss: 195.0423 - val_loss: 238.4029
#
# Epoch 00024: val_loss did not improve from 176.98497
# Epoch 25/40
# 250/250 [==============================] - 0s 1ms/step - loss: 197.0584 - val_loss: 185.8481
#
# Epoch 00025: val_loss did not improve from 176.98497
# Epoch 00025: early stopping
# 62/62 [==============================] - 2s 36ms/step
# Train on 250 samples, validate on 62 samples
# Epoch 1/40
# 250/250 [==============================] - 4s 16ms/step - loss: 3376.4011 - val_loss: 3933.9081
#
# Epoch 00001: val_loss improved from inf to 3933.90812, saving model to newModel/arrTemperature0_training_time_2_best_model_fold_4_config_8_4_2_ts100.h5
# Epoch 2/40
# 250/250 [==============================] - 0s 1ms/step - loss: 3353.4952 - val_loss: 3907.5053
#
# Epoch 00002: val_loss improved from 3933.90812 to 3907.50533, saving model to newModel/arrTemperature0_training_time_2_best_model_fold_4_config_8_4_2_ts100.h5
# Epoch 3/40
# 250/250 [==============================] - 0s 1ms/step - loss: 3313.8364 - val_loss: 3858.6549
#
# Epoch 00003: val_loss improved from 3907.50533 to 3858.65486, saving model to newModel/arrTemperature0_training_time_2_best_model_fold_4_config_8_4_2_ts100.h5
# Epoch 4/40
# 250/250 [==============================] - 0s 1ms/step - loss: 3249.2402 - val_loss: 3776.4683
#
# Epoch 00004: val_loss improved from 3858.65486 to 3776.46832, saving model to newModel/arrTemperature0_training_time_2_best_model_fold_4_config_8_4_2_ts100.h5
# Epoch 5/40
# 250/250 [==============================] - 0s 1ms/step - loss: 3155.8837 - val_loss: 3659.9324
#
# Epoch 00005: val_loss improved from 3776.46832 to 3659.93244, saving model to newModel/arrTemperature0_training_time_2_best_model_fold_4_config_8_4_2_ts100.h5
# Epoch 6/40
# 250/250 [==============================] - 0s 1ms/step - loss: 3028.7108 - val_loss: 3497.7043
#
# Epoch 00006: val_loss improved from 3659.93244 to 3497.70425, saving model to newModel/arrTemperature0_training_time_2_best_model_fold_4_config_8_4_2_ts100.h5
# Epoch 7/40
# 250/250 [==============================] - 0s 1ms/step - loss: 2860.1463 - val_loss: 3290.1661
#
# Epoch 00007: val_loss improved from 3497.70425 to 3290.16615, saving model to newModel/arrTemperature0_training_time_2_best_model_fold_4_config_8_4_2_ts100.h5
# Epoch 8/40
# 250/250 [==============================] - 0s 1ms/step - loss: 2654.4468 - val_loss: 3020.1033
#
# Epoch 00008: val_loss improved from 3290.16615 to 3020.10332, saving model to newModel/arrTemperature0_training_time_2_best_model_fold_4_config_8_4_2_ts100.h5
# Epoch 9/40
# 250/250 [==============================] - 0s 1ms/step - loss: 2391.6571 - val_loss: 2687.3283
#
# Epoch 00009: val_loss improved from 3020.10332 to 2687.32827, saving model to newModel/arrTemperature0_training_time_2_best_model_fold_4_config_8_4_2_ts100.h5
# Epoch 10/40
# 250/250 [==============================] - 0s 1ms/step - loss: 2074.7733 - val_loss: 2343.5610
#
# Epoch 00010: val_loss improved from 2687.32827 to 2343.56097, saving model to newModel/arrTemperature0_training_time_2_best_model_fold_4_config_8_4_2_ts100.h5
# Epoch 11/40
# 250/250 [==============================] - 0s 1ms/step - loss: 1731.6488 - val_loss: 1938.6850
#
# Epoch 00011: val_loss improved from 2343.56097 to 1938.68502, saving model to newModel/arrTemperature0_training_time_2_best_model_fold_4_config_8_4_2_ts100.h5
# Epoch 12/40
# 250/250 [==============================] - 0s 1ms/step - loss: 1378.3413 - val_loss: 1515.8806
#
# Epoch 00012: val_loss improved from 1938.68502 to 1515.88065, saving model to newModel/arrTemperature0_training_time_2_best_model_fold_4_config_8_4_2_ts100.h5
# Epoch 13/40
# 250/250 [==============================] - 0s 1ms/step - loss: 1065.7448 - val_loss: 1161.5863
#
# Epoch 00013: val_loss improved from 1515.88065 to 1161.58631, saving model to newModel/arrTemperature0_training_time_2_best_model_fold_4_config_8_4_2_ts100.h5
# Epoch 14/40
# 250/250 [==============================] - 0s 1ms/step - loss: 784.4691 - val_loss: 866.0721
#
# Epoch 00014: val_loss improved from 1161.58631 to 866.07209, saving model to newModel/arrTemperature0_training_time_2_best_model_fold_4_config_8_4_2_ts100.h5
# Epoch 15/40
# 250/250 [==============================] - 0s 2ms/step - loss: 575.7613 - val_loss: 647.6848
#
# Epoch 00015: val_loss improved from 866.07209 to 647.68484, saving model to newModel/arrTemperature0_training_time_2_best_model_fold_4_config_8_4_2_ts100.h5
# Epoch 16/40
# 250/250 [==============================] - 0s 2ms/step - loss: 433.3872 - val_loss: 494.7974
#
# Epoch 00016: val_loss improved from 647.68484 to 494.79745, saving model to newModel/arrTemperature0_training_time_2_best_model_fold_4_config_8_4_2_ts100.h5
# Epoch 17/40
# 250/250 [==============================] - 0s 1ms/step - loss: 342.0806 - val_loss: 397.2192
#
# Epoch 00017: val_loss improved from 494.79745 to 397.21920, saving model to newModel/arrTemperature0_training_time_2_best_model_fold_4_config_8_4_2_ts100.h5
# Epoch 18/40
# 250/250 [==============================] - 0s 1ms/step - loss: 291.4817 - val_loss: 333.2368
#
# Epoch 00018: val_loss improved from 397.21920 to 333.23684, saving model to newModel/arrTemperature0_training_time_2_best_model_fold_4_config_8_4_2_ts100.h5
# Epoch 19/40
# 250/250 [==============================] - 0s 2ms/step - loss: 259.8727 - val_loss: 292.0256
#
# Epoch 00019: val_loss improved from 333.23684 to 292.02565, saving model to newModel/arrTemperature0_training_time_2_best_model_fold_4_config_8_4_2_ts100.h5
# Epoch 20/40
# 250/250 [==============================] - 0s 1ms/step - loss: 239.8426 - val_loss: 261.8902
#
# Epoch 00020: val_loss improved from 292.02565 to 261.89017, saving model to newModel/arrTemperature0_training_time_2_best_model_fold_4_config_8_4_2_ts100.h5
# Epoch 21/40
# 250/250 [==============================] - 0s 1ms/step - loss: 221.4108 - val_loss: 238.8002
#
# Epoch 00021: val_loss improved from 261.89017 to 238.80021, saving model to newModel/arrTemperature0_training_time_2_best_model_fold_4_config_8_4_2_ts100.h5
# Epoch 22/40
# 250/250 [==============================] - 0s 1ms/step - loss: 202.4568 - val_loss: 218.2853
#
# Epoch 00022: val_loss improved from 238.80021 to 218.28533, saving model to newModel/arrTemperature0_training_time_2_best_model_fold_4_config_8_4_2_ts100.h5
# Epoch 23/40
# 250/250 [==============================] - 0s 1ms/step - loss: 181.5946 - val_loss: 196.4128
#
# Epoch 00023: val_loss improved from 218.28533 to 196.41276, saving model to newModel/arrTemperature0_training_time_2_best_model_fold_4_config_8_4_2_ts100.h5
# Epoch 24/40
# 250/250 [==============================] - 0s 1ms/step - loss: 161.6928 - val_loss: 194.4849
#
# Epoch 00024: val_loss improved from 196.41276 to 194.48493, saving model to newModel/arrTemperature0_training_time_2_best_model_fold_4_config_8_4_2_ts100.h5
# Epoch 25/40
# 250/250 [==============================] - 0s 1ms/step - loss: 148.1065 - val_loss: 174.6165
#
# Epoch 00025: val_loss improved from 194.48493 to 174.61654, saving model to newModel/arrTemperature0_training_time_2_best_model_fold_4_config_8_4_2_ts100.h5
# Epoch 26/40
# 250/250 [==============================] - 0s 2ms/step - loss: 131.8784 - val_loss: 155.3803
#
# Epoch 00026: val_loss improved from 174.61654 to 155.38026, saving model to newModel/arrTemperature0_training_time_2_best_model_fold_4_config_8_4_2_ts100.h5
# Epoch 27/40
# 250/250 [==============================] - 1s 2ms/step - loss: 121.2846 - val_loss: 144.0819
#
# Epoch 00027: val_loss improved from 155.38026 to 144.08193, saving model to newModel/arrTemperature0_training_time_2_best_model_fold_4_config_8_4_2_ts100.h5
# Epoch 28/40
# 250/250 [==============================] - 0s 2ms/step - loss: 110.7827 - val_loss: 140.1794
#
# Epoch 00028: val_loss improved from 144.08193 to 140.17937, saving model to newModel/arrTemperature0_training_time_2_best_model_fold_4_config_8_4_2_ts100.h5
# Epoch 29/40
# 250/250 [==============================] - 0s 2ms/step - loss: 104.0861 - val_loss: 135.9298
#
# Epoch 00029: val_loss improved from 140.17937 to 135.92981, saving model to newModel/arrTemperature0_training_time_2_best_model_fold_4_config_8_4_2_ts100.h5
# Epoch 30/40
# 250/250 [==============================] - 0s 1ms/step - loss: 101.7401 - val_loss: 130.2117
#
# Epoch 00030: val_loss improved from 135.92981 to 130.21171, saving model to newModel/arrTemperature0_training_time_2_best_model_fold_4_config_8_4_2_ts100.h5
# Epoch 31/40
# 250/250 [==============================] - 0s 2ms/step - loss: 98.3223 - val_loss: 127.1471
#
# Epoch 00031: val_loss improved from 130.21171 to 127.14714, saving model to newModel/arrTemperature0_training_time_2_best_model_fold_4_config_8_4_2_ts100.h5
# Epoch 32/40
# 250/250 [==============================] - 0s 2ms/step - loss: 95.7694 - val_loss: 126.2280
#
# Epoch 00032: val_loss improved from 127.14714 to 126.22801, saving model to newModel/arrTemperature0_training_time_2_best_model_fold_4_config_8_4_2_ts100.h5
# Epoch 33/40
# 250/250 [==============================] - 0s 1ms/step - loss: 93.8614 - val_loss: 123.5906
#
# Epoch 00033: val_loss improved from 126.22801 to 123.59061, saving model to newModel/arrTemperature0_training_time_2_best_model_fold_4_config_8_4_2_ts100.h5
# Epoch 34/40
# 250/250 [==============================] - 0s 1ms/step - loss: 91.8506 - val_loss: 120.2595
#
# Epoch 00034: val_loss improved from 123.59061 to 120.25946, saving model to newModel/arrTemperature0_training_time_2_best_model_fold_4_config_8_4_2_ts100.h5
# Epoch 35/40
# 250/250 [==============================] - 0s 2ms/step - loss: 90.3149 - val_loss: 119.3424
#
# Epoch 00035: val_loss improved from 120.25946 to 119.34243, saving model to newModel/arrTemperature0_training_time_2_best_model_fold_4_config_8_4_2_ts100.h5
# Epoch 36/40
# 250/250 [==============================] - 0s 1ms/step - loss: 88.4439 - val_loss: 118.3856
#
# Epoch 00036: val_loss improved from 119.34243 to 118.38557, saving model to newModel/arrTemperature0_training_time_2_best_model_fold_4_config_8_4_2_ts100.h5
# Epoch 37/40
# 250/250 [==============================] - 0s 1ms/step - loss: 87.1607 - val_loss: 116.1035
#
# Epoch 00037: val_loss improved from 118.38557 to 116.10355, saving model to newModel/arrTemperature0_training_time_2_best_model_fold_4_config_8_4_2_ts100.h5
# Epoch 38/40
# 250/250 [==============================] - 0s 1ms/step - loss: 85.6162 - val_loss: 115.7842
#
# Epoch 00038: val_loss improved from 116.10355 to 115.78417, saving model to newModel/arrTemperature0_training_time_2_best_model_fold_4_config_8_4_2_ts100.h5
# Epoch 39/40
# 250/250 [==============================] - 0s 1ms/step - loss: 84.6515 - val_loss: 116.2233
#
# Epoch 00039: val_loss did not improve from 115.78417
# Epoch 40/40
# 250/250 [==============================] - 0s 1ms/step - loss: 83.4283 - val_loss: 114.9158
#
# Epoch 00040: val_loss improved from 115.78417 to 114.91580, saving model to newModel/arrTemperature0_training_time_2_best_model_fold_4_config_8_4_2_ts100.h5
# 62/62 [==============================] - 2s 38ms/step

# %%
print ('start time: ',  datetime.timestamp(start_time))
print ('end time:', datetime.timestamp(end_time))
print ('training time: ', datetime.timestamp(end_time)-datetime.timestamp(start_time))
# Out:
# start time:  1573080036.861314
# end time: 1573080264.857186
# training time:  227.99587202072144

# %%
msescores
# Out:
# [{'path': 'newModel/arrTemperature0_training_time_0_best_model_fold_0_config_8_4_2_ts100.h5',
#   'mse': 121.60293724423363},
#  {'path': 'newModel/arrTemperature0_training_time_0_best_model_fold_1_config_8_4_2_ts100.h5',
#   'mse': 173.6720670669798},
#  {'path': 'newModel/arrTemperature0_training_time_0_best_model_fold_2_config_8_4_2_ts100.h5',
#   'mse': 118.82467479090536},
#  {'path': 'newModel/arrTemperature0_training_time_0_best_model_fold_3_config_8_4_2_ts100.h5',
#   'mse': 83.63773370558216},
#  {'path': 'newModel/arrTemperature0_training_time_0_best_model_fold_4_config_8_4_2_ts100.h5',
#   'mse': 144.50047253024192},
#  {'path': 'newModel/arrTemperature0_training_time_1_best_model_fold_0_config_8_4_2_ts100.h5',
#   'mse': 136.7141849578373},
#  {'path': 'newModel/arrTemperature0_training_time_1_best_model_fold_1_config_8_4_2_ts100.h5',
#   'mse': 125.5921652657645},
#  {'path': 'newModel/arrTemperature0_training_time_1_best_model_fold_2_config_8_4_2_ts100.h5',
#   'mse': 194.05529735934348},
#  {'path': 'newModel/arrTemperature0_training_time_1_best_model_fold_3_config_8_4_2_ts100.h5',
#   'mse': 110.69700327227193},
#  {'path': 'newModel/arrTemperature0_training_time_1_best_model_fold_4_config_8_4_2_ts100.h5',
#   'mse': 3252.934798702117},
#  {'path': 'newModel/arrTemperature0_training_time_2_best_model_fold_0_config_8_4_2_ts100.h5',
#   'mse': 71.81223563542441},
#  {'path': 'newModel/arrTemperature0_training_time_2_best_model_fold_1_config_8_4_2_ts100.h5',
#   'mse': 87.62066069103423},
#  {'path': 'newModel/arrTemperature0_training_time_2_best_model_fold_2_config_8_4_2_ts100.h5',
#   'mse': 3657.8428994455644},
#  {'path': 'newModel/arrTemperature0_training_time_2_best_model_fold_3_config_8_4_2_ts100.h5',
#   'mse': 176.9849666472404},
#  {'path': 'newModel/arrTemperature0_training_time_2_best_model_fold_4_config_8_4_2_ts100.h5',
#   'mse': 114.91579855642011}]

# %%
# timeList
model.summary()
# Out:
# Model: "sequential_15"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_29 (LSTM)               (None, 100, 8)            608
# _________________________________________________________________
# lstm_30 (LSTM)               (None, 100, 4)            208
# _________________________________________________________________
# flatten_15 (Flatten)         (None, 400)               0
# _________________________________________________________________
# dense_43 (Dense)             (None, 2)                 802
# _________________________________________________________________
# dense_45 (Dense)             (None, 1)                 3
# =================================================================
# Total params: 1,621
# Trainable params: 1,621
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Plot and see data distribution

from matplotlib import pyplot as plt
import seaborn as sns

def plotAttrDataOfId(data, compute, features):
    plt.figure(figsize=(30, 20))
    for i, v in enumerate(features):
        plt.subplot(10, 3, i+1)
        cDf = df[df['compute']==compute]
        plt.plot(cDf['timespan'], cDf[v])
        plt.title(v)
        plt.tight_layout()

# %%
# for x in np.random.randint(0, len(computes), 3):
#     plotAttrDataOfId(df, computes[x], features)

# %%
def plotDataDistribution(data, features):
    plt.figure(figsize=(30, 10))
    for i, v in enumerate(features):
        plt.subplot(3, 10, i+1)
        sns.distplot(list(data[v].values))
        plt.title(v)
    plt.tight_layout()

# %%
# plotDataDistribution(df, features)

# %%
from datetime import datetime
print(datetime.now().strftime("%H_%M_%S"))

# %%
[i for i in range(1,11
                 )]

# %%
sns.distplot(y_train)

# %%
sns.distplot(y_test)

# %%
print (type(X_dfs[0]))
